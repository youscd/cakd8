# %% [markdown]
# #### customer_channel, buydata 테이블

# %%
# 고객 채널이용정보 CUSTOMER_CHANNEL (2015.10 ~ 2015.12)
#customer_channel = pd.read_excel('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/CUSTOMER_CHANNEL.xlsx')
customer_channel = pd.merge(custdemo_df, channel_df, on='고객번호', how='outer')
customer_channel = pd.merge(customer_channel, membership_df, on='고객번호', how='outer')
customer_channel.to_csv("/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/customer_channel.csv", index = False)

customer_channel_df = customer_channel.copy()
customer_channel_df

# %%
# 구매정보 BUYDATA
# prodpur_df : 제휴사, 영수증번호, 소분류코드, 고객번호, 구매일자, 구매시간, 구매금액
# custdemo_df : 고객번호, 성별, 연령대
# prodcl_df : 중분류명, 소분류명

a = prodpur_df.drop(columns=['대분류코드', '중분류코드'])
b = custdemo_df.iloc[:, :3]
c = prodcl_df.iloc[:, 4:]

d = pd.merge(a, b, on='고객번호', how='outer')
buydata = pd.merge(d, c, on='소분류코드', how='outer')
buydata.to_csv("/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/buydata.csv", index = False)

buydata[:5]

# %%
buydata_df = buydata.copy()
buydata_df

# %% [markdown]
# # 데이터 불러오기

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 20 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 1s (8,232 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
import numpy as np
import pandas as pd

# %%
# 경쟁사이용 COMPET
#compet = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/경쟁사이용 (COMPET).txt', encoding='cp949')

# 멤버쉽여부 MEMBERSHIP
#membership = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/멤버십여부 (MEMBERSHIP).txt', encoding='cp949')

# 채널이용 CHANNEL
#channel = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/채널이용 (CHANNEL).txt', encoding='cp949')

# 고객DEMO(정보) CUSTDEMO
#custdemo = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/고객DEMO (CUSTDEMO).txt', encoding='cp949')

# 상품분류 PRODCL
#prodcl = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/상품분류 (PRODCL).txt', encoding='cp949')
#prodcl = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/product (중분류명 수정).csv')

# 구매상품 PRODPUR
#prodpur = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/구매상품TR (PRODPUR).txt', encoding='cp949')

# 고객 채널이용정보 CUSTOMER_CHANNEL (2015.10 ~ 2015.12)
#customer_channel = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/customer_channel.csv')

# 구매정보 BUYDATA
#buydata = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/buydata.csv')
buydata = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/purchase6.csv')

# %%
#compet.sort_values(by = '고객번호', inplace=True, ignore_index=True)

'''
membership.sort_values(by = '고객번호', inplace=True, ignore_index=True)
channel.sort_values(by = '고객번호', inplace=True, ignore_index=True)
custdemo.sort_values(by = '고객번호', inplace=True, ignore_index=True)
prodpur.sort_values(by = '고객번호', inplace=True, ignore_index=True)
'''
# Out:
# "\nmembership.sort_values(by = '고객번호', inplace=True, ignore_index=True)\nchannel.sort_values(by = '고객번호', inplace=True, ignore_index=True)\ncustdemo.sort_values(by = '고객번호', inplace=True, ignore_index=True)\nprodpur.sort_values(by = '고객번호', inplace=True, ignore_index=True)\n"

# %%
# 원본 데이터 copy
#compet_df = compet.copy()
#customer_channel_df = customer_channel.copy()
buydata_df = buydata.iloc[:, 1:]

'''
membership_df = membership.copy()
channel_df = channel.copy()
custdemo_df = custdemo.copy()
prodcl_df = prodcl.copy()
prodpur_df = prodpur.copy()
'''
# Out:
# '\nmembership_df = membership.copy()\nchannel_df = channel.copy()\ncustdemo_df = custdemo.copy()\nprodcl_df = prodcl.copy()\nprodpur_df = prodpur.copy()\n'

# %%
buydata_df[:5]
# Out:
#    고객번호 성별    연령대       거주지역 제휴사  중분류명  소분류명    영수증번호  점포코드      구매일자  구매시간  \
# 0     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  1456379    12  20140228    15
# 1     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  2751160    12  20140919    15
# 2     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  1307657    12  20140130    11
# 3     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  3960475    12  20150327    12
# 4     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  5602223    12  20151130    17
#
#     구매금액
# 0   9500
# 1   5000
# 2  19810
# 3   1000
# 4   6800

# %%
buydata_df['분기'] = np.where(buydata_df['구매일자'] < 20140401, '2014_1분기',
                                  np.where(buydata_df['구매일자'] < 20140701, '2014_2분기',
                                           np.where(buydata_df['구매일자'] < 20141001, '2014_3분기',
                                                    np.where(buydata_df['구매일자'] < 20150101, '2014_4분기',
                                                             np.where(buydata_df['구매일자'] < 20150401, '2015_1분기',
                                                                      np.where(buydata_df['구매일자'] < 20150701, '2015_2분기',
                                                                               np.where(buydata_df['구매일자'] < 20151001, '2015_3분기','2015_4분기')))))))

buydata_df[:5]
# Out:
#    고객번호 성별    연령대       거주지역 제휴사  중분류명  소분류명    영수증번호  점포코드      구매일자  구매시간  \
# 0     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  1456379    12  20140228    15
# 1     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  2751160    12  20140919    15
# 2     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  1307657    12  20140130    11
# 3     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  3960475    12  20150327    12
# 4     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  5602223    12  20151130    17
#
#     구매금액        분기
# 0   9500  2014_1분기
# 1   5000  2014_3분기
# 2  19810  2014_1분기
# 3   1000  2015_1분기
# 4   6800  2015_4분기

# %%
buydata_df.shape
# Out:
# (28593030, 12)

# %%
buydata_df.isna().sum()
# Out:
# 고객번호     0
# 성별       0
# 연령대      0
# 거주지역     0
# 제휴사      0
# 중분류명     0
# 소분류명     0
# 영수증번호    0
# 점포코드     0
# 구매일자     0
# 구매시간     0
# 구매금액     0
# dtype: int64

# %%
len(buydata_df['점포코드'].unique())
# Out:
# 593

# %%
#buydata_df['구매일자(년도)'] = buydata_df['구매일자'].astype('string').str[:4]

# %% [markdown]
# # 데이터 탐색

# %%
buydata_df[buydata_df['중분류명'] == '명품']
# Out:
#            고객번호 성별      연령대       거주지역 제휴사 중분류명        소분류명    영수증번호  점포코드  \
# 816           1  M    60세이상  서울특별시 강남구   A   명품        수입잡화  3765507    12
# 2087          2  M    60세이상    경기도 김포시   A   명품        수입의류  3824864     7
# 2088          2  M    60세이상    경기도 김포시   A   명품        수입의류  3832516     7
# 2089          2  M    60세이상    경기도 김포시   A   명품        수입의류  3832517     7
# 2090          2  M    60세이상    경기도 김포시   A   명품         직수입  3953332     7
# ...         ... ..      ...        ...  ..  ...         ...      ...   ...
# 28589778  19378  F  45세~49세    경기도 김포시   A   명품         직수입  4917224    44
# 28589779  19378  F  45세~49세    경기도 김포시   A   명품         직수입  5273643    44
# 28589780  19378  F  45세~49세    경기도 김포시   A   명품         직수입  4634600    44
# 28589781  19378  F  45세~49세    경기도 김포시   A   명품         직수입  4759638    44
# 28590067  19379  F  20세~24세  서울특별시 동작구   A   명품  global 편집샵  5773188    45
#
#               구매일자  구매시간    구매금액
# 816       20150225    15  503500
# ...

# %%
# 4개의 제휴사를 모두 통틀어 매출액이 큰 중분류명 top10
buydata_df.groupby('중분류명')[['구매금액']].sum().sort_values(by='구매금액', ascending=False)[:10]
# Out:
#               구매금액
# 중분류명
# 캐주얼    97483124440
# 명품     64602297810
# 화장품    34088727860
# 스포츠    25708407210
# 골프용품   20203314490
# 가공식품   18469825840
# 아동     16775759320
# 트래디셔널  16593697340
# 디자이너   14331569550
# 대형가전   13664427250

# %%
# 4개의 제휴사를 모두 통틀어 구매횟수가 많은 중분류명 top10
buydata_df.groupby('중분류명')[['구매금액']].count().sort_values(by='구매금액', ascending=False)[:10]
# Out:
#          구매금액
# 중분류명
# 가공식품  1260715
# 농산물    820228
# 스낵     781051
# 라면     565608
# 캐주얼    528858
# 우유     442587
# 흰우유    437727
# 맥주     387188
# 국산과일   357115
# 두채류    353824

# %% [markdown]
# ## 점포별 매출이 높은 상품 top10

# %%
print(buydata_df[buydata_df['제휴사'] == 'A']['점포코드'].unique(), '\n')
print(buydata_df[buydata_df['제휴사'] == 'B']['점포코드'].unique(), '\n')
print(buydata_df[buydata_df['제휴사'] == 'C']['점포코드'].unique(), '\n')
print(buydata_df[buydata_df['제휴사'] == 'D']['점포코드'].unique(), '\n')
# Out:
# [12  2 20 26  7  1 43  3  6 13 24 31 39  9 10 11 35 42  8 48 41 29  4 15
#  37 22 17 21 25 44 16 18  5 27 45 14 50 30 47 23 40 36 19 32 34 33 28 46
#  49 38 51]
#
# [ 13   4   7  18   9   8  17  11 126 111   6  19  12  76 129  62  34  32
#   58  72 132  29  51 107   3  14  22  61 109  16  15  94  49  24  82  21
#   68  25  54  65  96  38  53  10  36  20 105  60  30  83  90  39 113  44
#   43 108 125  91  50  63 127  41  99  84  57  89  93 106  71 119  95  80
#   67  46 128 102  87  88  59  74   1 114  97  70 100  23   5 115  98 121
#  124  45  48  27  66  85 120  52  28  56 110  40  69 123  92  75  86 131
#  133 134  47 135  55  26  77  81 122  64 112 104   2  42 116  37  35  73
#  130  78 118  79  33  31 101 103 117]
#
# [318  96 531  34 475 127  19 315 331  48 189  11 250 327 329 261  25 511
#   15 286   1 132 164 402 365 221 117 312 154 109  44  83  69 490 195 163
#  156 201  21 268  47 129 131  99  13 539 366 236  28 139  35 112  22  40
# ...

# %%
# 점포 별 매출이 높은 상품 top10
a = buydata_df.groupby(['점포코드', '중분류명'], as_index=False)[['구매금액']].sum()
a
# Out:
#         점포코드         중분류명    구매금액
# 0          1  BABY/INFANT  261280
# 1          1       BOYS 1   89870
# 2          1       BOYS 2  118880
# 3          1      DIY욕실용품   19750
# 4          1  EDUCATION 1  219400
# ...      ...          ...     ...
# 105385   593       케첩마요네즈     990
# 105386   593        쿠키케이크   28120
# 105387   593         탄산음료   26650
# 105388   593          해물류    5980
# 105389   593          화장지  135510
#
# [105390 rows x 3 columns]

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105390 entries, 0 to 105389
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   점포코드    105390 non-null  int64
#  1   중분류명    105390 non-null  object
#  2   구매금액    105390 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 2.4+ MB

# %%
s = a.query("점포코드 == 1").sort_values(by='구매금액', ascending=False)[:10].index
s
# Out:
# Int64Index([187, 493, 565, 54, 15, 163, 310, 146, 224, 520], dtype='int64')

# %%
s[2]
# Out:
# 565

# %%
codes = a['점포코드'].unique().tolist()
codes

# %%
top_index_lst = []

for code in codes:
  indx = a.query(f"점포코드 == {code}").sort_values(by='구매금액', ascending=False)[:10].index
  for j in range(10):
    try:
      #print(indx[j])
      top_index_lst.append(indx[j])
    except:
      pass

top_index_lst

# %%
store_sales_top10 = a.iloc[top_index_lst]
store_sales_top10 = store_sales_top10.reset_index().iloc[:, 1:]
store_sales_top10
# Out:
#       점포코드   중분류명         구매금액
# 0        1     명품  15738462530
# 1        1    캐주얼   8896397780
# 2        1    화장품   3413412910
# 3        1   골프용품   1491651340
# 4        1   가공식품   1468550240
# ...    ...    ...          ...
# 5886   593     소주        48180
# 5887   593     우유        47070
# 5888   593     생수        29060
# 5889   593  쿠키케이크        28120
# 5890   593    근채류        27420
#
# [5891 rows x 3 columns]

# %%
print(store_sales_top10[store_sales_top10['점포코드'] == 1]['중분류명'].unique())
# Out:
# ['명품' '캐주얼' '화장품' '골프용품' '가공식품' '디자이너' '스포츠' '농산물' '보석' '트래디셔널']

# %% [markdown]
# ## 점포별 구매횟수가 높은 상품 top10

# %%
# 점포 별 구매횟수가 높은 상품 top10
b = buydata_df.groupby(['점포코드', '중분류명'], as_index=False)[['구매금액']].count().rename(columns={'구매금액' : '구매횟수'})
b
# Out:
#         점포코드         중분류명  구매횟수
# 0          1  BABY/INFANT     8
# 1          1       BOYS 1     4
# 2          1       BOYS 2     3
# 3          1      DIY욕실용품     1
# 4          1  EDUCATION 1     5
# ...      ...          ...   ...
# 105385   593       케첩마요네즈     1
# 105386   593        쿠키케이크    19
# 105387   593         탄산음료    12
# 105388   593          해물류     2
# 105389   593          화장지     6
#
# [105390 rows x 3 columns]

# %%
top_index_lst = []

for code in codes:
  indx = a.query(f"점포코드 == {code}").sort_values(by='구매횟수', ascending=False)[:10].index
  for j in range(10):
    try:
      #print(indx[j])
      top_index_lst.append(indx[j])
    except:
      pass

top_index_lst

# %%
store_buycount_top10 = a.iloc[top_index_lst]
store_buycount_top10 = store_buycount_top10.reset_index().iloc[:, 1:]
store_buycount_top10
# Out:
#       점포코드  중분류명   구매횟수
# 0        1  가공식품  99911
# 1        1   농산물  43958
# 2        1   캐주얼  24296
# 3        1   화장품  20978
# 4        1  차/커피  18054
# ...    ...   ...    ...
# 5886   593  냉장축산     13
# 5887   593  탄산음료     12
# 5888   593   발효유     11
# 5889   593   엽채류     10
# 5890   593   계란류     10
#
# [5891 rows x 3 columns]

# %% [markdown]
# ## 중분류명 별 연매출 증감

# %%
# 중분류명 별 연매출 증감
#buydata_df['구매일자_년도'] = buydata_df['구매일자'].astype('string').str[:4]
#buydata_df[:5]

# %%
buydata_df_2014 = buydata_df.query("구매일자 >= 20140101 & 구매일자 <= 20141231")
buydata_df_2015 = buydata_df.query("구매일자 >= 20150101 & 구매일자 <= 20151231")

# %%
a = buydata_df_2014.groupby('중분류명')[['구매금액']].sum()
b = buydata_df_2015.groupby('중분류명')[['구매금액']].sum()
c = pd.merge(a,b, on = '중분류명')
c.rename(columns = {'구매금액_x' : '2014', '구매금액_y' : '2015'}, inplace=True)
c
# Out:
#                   2014       2015
# 중분류명
# BABY/INFANT  176433830  152488120
# BOYS 1       169041860  674956860
# BOYS 2        29437230  103565230
# DIY욕실용품        1266600    5653650
# EDUCATION 1  100566300  358422229
# ...                ...        ...
# 황태            13140840   58771610
# 훼이셜케어         20516600   79914110
# 휴대폰용품          3699190   12647070
# 휴지통            3444090   10128410
# 흰우유          906113584  878896872
#
# [540 rows x 2 columns]

# %%
c['증감'] = c['2015'] - c['2014']
c['%'] = round((((c['2015'] / c['2014']) - 1) * 100),2)

#c['2014'] = c['2014'].apply(lambda x : '{:,.0f}'.format(x))
#c['2015'] = c['2015'].apply(lambda x : '{:,.0f}'.format(x))
#c['증감'] = c['증감'].apply(lambda x : '{:,.0f}'.format(x))

# %%
c.sort_values(by='증감')[:10]
# Out:
#                2014         2015          증감      %
# 중분류명
# 분유       2203843750    206689110 -1997154640 -90.62
# 스포츠     13422404420  12286002790 -1136401630  -8.47
# 스낵       1913483204   1279307488  -634175716 -33.14
# 피혁잡화     4486546890   3852634360  -633912530 -14.13
# 구두       5552988200   4955461150  -597527050 -10.76
# 헤어스타일링    584368710     88741670  -495627040 -84.81
# 트래디셔널    8495496850   8098200490  -397296360  -4.68
# 남성정장     3382939400   2995145210  -387794190 -11.46
# 모피/피혁    3299015150   2954898790  -344116360 -10.43
# 등산        310981390      8032290  -302949100 -97.42

# %%
c.sort_values(by='증감', ascending=False)[:10]
# Out:
#                2014         2015          증감       %
# 중분류명
# 명품      28803579870  35798717940  6995138070   24.29
# 캐주얼     47090901680  50392222760  3301321080    7.01
# 기초화장품     555570490   2256743260  1701172770  306.20
# 대형가전     6129108830   7535318420  1406209590   22.94
# 커피류       767004265   2124100829  1357096564  176.93
# 가구       4437722970   5454765860  1017042890   22.92
# 남성 트랜디   4163390270   5034136820   870746550   20.91
# 가공식품     8822245760   9647580080   825334320    9.36
# 커리어      5877755560   6652102420   774346860   13.17
# 브랜드       325610140   1012472750   686862610  210.95

# %% [markdown]
# ### 제휴사별 중분류명 연매출 증감

# %% [markdown]
# #### 제휴사 A

# %%
market_A = buydata_df[buydata_df['제휴사'] == 'A']
market_A_2014 = market_A.query("구매일자 >= 20140101 & 구매일자 <= 20141231")
market_A_2015 = market_A.query("구매일자 >= 20150101 & 구매일자 <= 20151231")

# %%
a = market_A_2014.groupby('중분류명')[['구매금액']].sum()
b = market_A_2015.groupby('중분류명')[['구매금액']].sum()
c = pd.merge(a,b, on = '중분류명')
c.rename(columns = {'구매금액_x' : '2014', '구매금액_y' : '2015'}, inplace=True)
c
# Out:
#                2014         2015
# 중분류명
# 가공식품     8822245760   9647580080
# 가구       4380515470   5291978250
# 건강식품     3507667720   3959627560
# 골프용품    10133672380  10069642110
# 교복         60804250     13181000
# 구두       5552988200   4955461150
# 기타         12544470     50005810
# 기타의류       88058700    153075200
# 남성 트랜디   4163390270   5034136820
# 남성정장     3382939400   2995145210
# 남성캐주얼    1578371130   1756013940
# 농산물      6313640260   6063873800
# 대형가전     6129108830   7535318420
# 디자이너     7179714830   7151854720
# 란제리/내의   2287926450   2387215920
# 명품      28803579870  35798717940
# 모피/피혁    3299015150   2954898790
# 문구/팬시     309381900    324703160
# 보석       3953333920   4597679450
# 생활잡화     2027232460   2487520070
# 섬유잡화     2984002920   2883107850
# 셔츠       1553442170   1565560960
# 소형가전      921642320   1146446590
# 수산품      2991275270   3118676140
# 스포츠     13422404420  12286002790
# 시티웨어     4452467510   4555277230
# 식기       1895436770   2123207650
# ...

# %%
c['증감'] = c['2015'] - c['2014']
c['%'] = round((((c['2015'] / c['2014']) - 1) * 100),2)

c['2014'] = c['2014'].apply(lambda x : '{:,.0f}'.format(x))
c['2015'] = c['2015'].apply(lambda x : '{:,.0f}'.format(x))
c['증감'] = c['증감'].apply(lambda x : '{:,.0f}'.format(x))

# %%
c.sort_values(by='증감')[:10]
# Out:
#                   2014            2015              증감      %
# 중분류명
# 스포츠     13,422,404,420  12,286,002,790  -1,136,401,630  -8.47
# 섬유잡화     2,984,002,920   2,883,107,850    -100,895,070  -3.38
# 준보석/시계   1,305,780,500   1,203,160,110    -102,620,390  -7.86
# 침구/수예    3,923,035,520   3,784,844,750    -138,190,770  -3.52
# 농산물      6,313,640,260   6,063,873,800    -249,766,460  -3.96
# 축산가공       999,578,680     972,588,820     -26,989,860  -2.70
# 디자이너     7,179,714,830   7,151,854,720     -27,860,110  -0.39
# 모피/피혁    3,299,015,150   2,954,898,790    -344,116,360 -10.43
# 남성정장     3,382,939,400   2,995,145,210    -387,794,190 -11.46
# 트래디셔널    8,495,496,850   8,098,200,490    -397,296,360  -4.68

# %%
c.sort_values(by='증감', ascending=False)[:10]
# Out:
#                   2014            2015             증감      %
# 중분류명
# 란제리/내의   2,287,926,450   2,387,215,920     99,289,470   4.34
# 가구       4,380,515,470   5,291,978,250    911,462,780  20.81
# 남성 트랜디   4,163,390,270   5,034,136,820    870,746,550  20.91
# 가공식품     8,822,245,760   9,647,580,080    825,334,320   9.36
# 커리어      5,877,755,560   6,652,102,420    774,346,860  13.17
# 기타의류        88,058,700     153,075,200     65,016,500  73.83
# 보석       3,953,333,920   4,597,679,450    644,345,530  16.30
# 젓갈/반찬      769,622,540     830,151,080     60,528,540   7.86
# 명품      28,803,579,870  35,798,717,940  6,995,138,070  24.29
# 화장품     16,615,318,810  17,193,973,170    578,654,360   3.48

# %% [markdown]
# ## B 제휴사의 매출 증감

# %% [markdown]
# ### 중분류명 연매출 증감

# %%
market_B = buydata_df[buydata_df['제휴사'] == 'B']

# %%
market_B_2014 = market_B.query("구매일자 >= 20140101 & 구매일자 <= 20141231")
market_B_2015 = market_B.query("구매일자 >= 20150101 & 구매일자 <= 20151231")

# %%
a = market_B_2014.groupby('중분류명')[['구매금액']].sum()
b = market_B_2015.groupby('중분류명')[['구매금액']].sum()
c = pd.merge(a,b, on = '중분류명')
c.rename(columns = {'구매금액_x' : '2014', '구매금액_y' : '2015'}, inplace=True)
c[:10]
# Out:
#              2014         2015
# 중분류명
# 가공식품  15530409913  12929989186
# 가구      254562920    254062310
# 건강         418900     10831900
# 건강가전      3088400        54000
# 건강식품    638222729    559215172
# 골프용품    119714690    100366850
# 구두      244958280    167390000
# 기타     1131817980    949689783
# 기타의류      3623730     12295760
# 남성정장     75191200    203264300

# %%
c['증감'] = c['2015'] - c['2014']
c['%'] = round((((c['2015'] / c['2014']) - 1) * 100),2)

#c['2014'] = c['2014'].apply(lambda x : '{:,.0f}'.format(x))
#c['2015'] = c['2015'].apply(lambda x : '{:,.0f}'.format(x))
#c['증감'] = c['증감'].apply(lambda x : '{:,.0f}'.format(x))

# %%
c.sort_values(by='증감')[:10]
# Out:
#                2014         2015          증감      %
# 중분류명
# 가공식품    15530409913  12929989186 -2600420727 -16.74
# 스포츠      1189761036    382243227  -807517809 -67.87
# 아동       2052463909   1481673137  -570790772 -27.81
# 차/커피     2518940850   1957619226  -561321624 -22.28
# 남성캐주얼     423031700     52563500  -370468200 -87.57
# 주방용품     1002993720    701052410  -301941310 -30.10
# 미용용품     1126976730    893218775  -233757955 -20.74
# 기타       1131817980    949689783  -182128197 -16.09
# 란제리/내의    945973539    823862520  -122111019 -12.91
# 피혁잡화      292598220    184267480  -108330740 -37.02

# %%
c.sort_values(by='증감', ascending=False)[:10]
# Out:
#              2014        2015         증감       %
# 중분류명
# 문구/팬시   826783951  1717435249  890651298  107.72
# 농산물    6352886179  7209232861  856346682   13.48
# 행사      667709079  1317121202  649412123   97.26
# 육류     3734984283  4344413674  609429391   16.32
# 선물      278314320   545703385  267389065   96.07
# 생활잡화   3848319451  4098284071  249964620    6.50
# 시티웨어    113747840   345364430  231616590  203.62
# 섬유잡화    120500140   273730280  153230140  127.16
# 젓갈/반찬   893274263  1044443314  151169051   16.92
# 화장품    2774470758  2921228050  146757292    5.29

# %% [markdown]
# ### 분기별 매출이 감소한 상품 (중분류명)

# %%
market_B
# Out:
#            고객번호 성별      연령대       거주지역 제휴사  중분류명    소분류명     영수증번호  점포코드  \
# 874           1  M    60세이상  서울특별시 강남구   B   농산물    기능성미   7068855    13
# 875           1  M    60세이상  서울특별시 강남구   B    식당  뷔페레스토랑   7069008    13
# 876           1  M    60세이상  서울특별시 강남구   B    식당  뷔페레스토랑     93124     4
# 877           1  M    60세이상  서울특별시 강남구   B    식당  한식레스토랑    117058     4
# 878           1  M    60세이상  서울특별시 강남구   B    식당  한식레스토랑    114660     4
# ...         ... ..      ...        ...  ..   ...     ...       ...   ...
# 28592799  19383  F  25세~29세   경상남도 함양군   B  가공식품     냉동밥  10047211    93
# 28592800  19383  F  25세~29세   경상남도 함양군   B  가공식품    봉지라면  10355251   107
# 28592801  19383  F  25세~29세   경상남도 함양군   B  가공식품     컵라면   9832756    85
# 28592802  19383  F  25세~29세   경상남도 함양군   B  가공식품   3분요리류  10047211    93
# 28592803  19383  F  25세~29세   경상남도 함양군   B  가공식품    즉석밥류   9832756    85
#
#               구매일자  구매시간   구매금액        분기
# 874       20141023    14  22000  2014_4분기
# ...

# %%
# B 제휴사 상품의 분기별 매출
q_product = market_B.groupby(['중분류명', '분기'], as_index=False)[['구매금액']].sum()
q_product
# Out:
#      중분류명        분기        구매금액
# 0    가공식품  2014_1분기  3979110843
# 1    가공식품  2014_2분기  4193460505
# 2    가공식품  2014_3분기  4113131414
# 3    가공식품  2014_4분기  3244707151
# 4    가공식품  2015_1분기  3418522475
# ..    ...       ...         ...
# 352   화장품  2014_4분기   729953210
# 353   화장품  2015_1분기   768988440
# 354   화장품  2015_2분기   722101820
# 355   화장품  2015_3분기   804303330
# 356   화장품  2015_4분기   625834460
#
# [357 rows x 3 columns]

# %%
len(q_product['중분류명'].unique())
# Out:
# 50

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

fig = px.line(q_product, x="분기", y="구매금액", color='중분류명')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 분기별 매출 감소 상품: 가공식품, 건강가전, 건강식품, 골프용품, 남성캐주얼

# %%
q_product
# Out:
#      중분류명        분기        구매금액
# 0    가공식품  2014_1분기  3979110843
# 1    가공식품  2014_2분기  4193460505
# 2    가공식품  2014_3분기  4113131414
# 3    가공식품  2014_4분기  3244707151
# 4    가공식품  2015_1분기  3418522475
# ..    ...       ...         ...
# 352   화장품  2014_4분기   729953210
# 353   화장품  2015_1분기   768988440
# 354   화장품  2015_2분기   722101820
# 355   화장품  2015_3분기   804303330
# 356   화장품  2015_4분기   625834460
#
# [357 rows x 3 columns]

# %%
q_product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   중분류명    357 non-null    object
#  1   분기      357 non-null    object
#  2   구매금액    357 non-null    int64
# dtypes: int64(1), object(2)
# memory usage: 8.5+ KB

# %% [markdown]
# ### 매출이 감소한 상품이 다른 제휴사에서는 매출이 어땠는지
# 스포츠, 가공식품, 건강식품, 기타, 남성 캐주얼, 란제리, 소형가구, 미용용품, 차/커피

# %%
buydata_df
# Out:
#            고객번호 성별      연령대       거주지역 제휴사  중분류명      소분류명    영수증번호  점포코드  \
# 0             1  M    60세이상  서울특별시 강남구   A  일용잡화      위생세제  1456379    12
# 1             1  M    60세이상  서울특별시 강남구   A  일용잡화      위생세제  2751160    12
# 2             1  M    60세이상  서울특별시 강남구   A  일용잡화      위생세제  1307657    12
# 3             1  M    60세이상  서울특별시 강남구   A  일용잡화      위생세제  3960475    12
# 4             1  M    60세이상  서울특별시 강남구   A  일용잡화      위생세제  5602223    12
# ...         ... ..      ...        ...  ..   ...       ...      ...   ...
# 28593025  19383  F  25세~29세   경상남도 함양군   D   화장품     아이섀도우   240249    31
# 28593026  19383  F  25세~29세   경상남도 함양군   D   화장품    메이크업세트   237806    30
# 28593027  19383  F  25세~29세   경상남도 함양군   D   화장품   립글로즈/틴트   240283    31
# 28593028  19383  F  25세~29세   경상남도 함양군   D   화장품   립글로즈/틴트   240284    31
# 28593029  19383  F  25세~29세   경상남도 함양군   D   화장품  일반네일/케어류   237673    30
#
#               구매일자  구매시간   구매금액        분기
# ...

# %%
# 스포츠, 가공식품, 건강식품, 기타, 남성 캐주얼, 란제리, 소형가구, 미용용품, 차/커피
# 분기별 스포츠 상품 총 매출액
sports = pd.pivot_table(data=buydata_df.query("중분류명 == '스포츠'"), values='구매금액', index='분기', columns='제휴사', aggfunc='sum')
sports
# Out:
# 제휴사                A          B
# 분기
# 2014_1분기  2997158970  312135810
# 2014_2분기  3619007940  424815362
# 2014_3분기  2445026010  365780494
# 2014_4분기  4361211500   87029370
# 2015_1분기  2892378660   67139650
# 2015_2분기  2999979440  118678925
# 2015_3분기  2385430700  132337462
# 2015_4분기  4008213990   64087190

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(10, 5))
sns.lineplot(data=sports)
plt.xticks(rotation=45)
plt.title('분기별 스포츠 상품 총 매출액 비교')
plt.savefig('분기별 스포츠 상품 총 매출액 비교.png')
plt.show()

# %%
# 스포츠, 가공식품, 건강식품, 기타, 남성 캐주얼, 란제리, 소형가구, 미용용품, 차/커피
# 분기별 가공식품 총 매출액
food = pd.pivot_table(data=buydata_df.query("중분류명 == '가공식품'"), values='구매금액', index='분기', columns='제휴사', aggfunc='sum')
food
# Out:
# 제휴사                A           B           C         D
# 분기
# 2014_1분기  2091727610  3979110843  1513664984   6108480
# 2014_2분기  2029013620  4193460505  1508159713   5769850
# 2014_3분기  2355735270  4113131414  1609051820   6283850
# 2014_4분기  2345769260  3244707151  1806222138  11290260
# 2015_1분기  2456498670  3418522475  1821402352  14501070
# 2015_2분기  2206895760  3092386435  1694571713  10913060
# 2015_3분기  2550424870  3511764958  1829528608  10540890
# 2015_4분기  2433760780  2907315318  1705255097  12609640

# %%
#plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(10, 5))
sns.lineplot(data=food)
#plt.xticks(rotation=45)
plt.title('분기별 가공식품 총 매출액 비교')
plt.savefig('분기별 가공식품 총 매출액 비교.png')
plt.show()

# %%
# 스포츠, 가공식품, 건강식품, 기타, 남성 캐주얼, 란제리, 소형가구, 미용용품, 차/커피
# 분기별 건강식품 총 매출액
h_food = pd.pivot_table(data=buydata_df.query("중분류명 == '건강식품'"), values='구매금액', index='분기', columns='제휴사', aggfunc='sum') 
h_food
# Out:
# 제휴사                A          B         C        D
# 분기
# 2014_1분기   925982920  169992670  21742090   608750
# 2014_2분기   764885110  144482702  10663370   611790
# 2014_3분기  1108155920  209174231  17852050   845300
# 2014_4분기   708643770  114573126   9797570  1175180
# 2015_1분기  1040224780  161655153  20654470  1186100
# 2015_2분기   903582530  135655724  12267170  1545440
# 2015_3분기  1269169690  151840260  19150480  1364030
# 2015_4분기   746650560  110064035   9414336  1495970

# %%
#plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(10, 5))
sns.lineplot(data=h_food)
#plt.xticks(rotation=45)
plt.title('분기별 건강식품 총 매출액 비교')
plt.savefig('분기별 건강식품 총 매출액 비교.png')
plt.show()

# %%
# 스포츠, 가공식품, 건강식품, 기타, 남성 캐주얼, 란제리, 소형가구, 미용용품, 차/커피
# 분기별 기타 상품 총 매출액
etc_product = pd.pivot_table(data=buydata_df.query("중분류명 == '기타'"), values='구매금액', index='분기', columns='제휴사', aggfunc='sum') 
etc_product
# Out:
# 제휴사                A            B
# 분기
# 2014_1분기         NaN  294943740.0
# 2014_2분기         NaN  231259886.0
# 2014_3분기     73600.0  354400122.0
# 2014_4분기  12470870.0  251214232.0
# 2015_1분기  12009870.0  252615811.0
# 2015_2분기   5035050.0  231857007.0
# 2015_3분기  12623470.0  249176033.0
# 2015_4분기  20337420.0  216040932.0

# %%
#plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(10, 5))
sns.lineplot(data=etc_product)
#plt.xticks(rotation=45)
plt.title('분기별 기타 상품 총 매출액 비교')
plt.savefig('분기별 기타 상품 총 매출액 비교.png')
plt.show()

# %%
# 스포츠, 가공식품, 건강식품, 기타, 남성 캐주얼, 란제리, 소형가구, 미용용품, 차/커피
# 분기별 남성캐주얼 상품 총 매출액
men_prod = pd.pivot_table(data=buydata_df.query("중분류명 == '남성캐주얼'"), values='구매금액', index='분기', columns='제휴사', aggfunc='sum')
men_prod
# Out:
# 제휴사               A          B
# 분기
# 2014_1분기  324297340  135501200
# 2014_2분기  454725000  156839000
# 2014_3분기  247239320  113284390
# 2014_4분기  552109470   17407110
# 2015_1분기  384806050   10855420
# 2015_2분기  430541950   11120510
# 2015_3분기  297008060    9676540
# 2015_4분기  643657880   20911030

# %%
#plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(10, 5))
sns.lineplot(data=men_prod)
#plt.xticks(rotation=45)
plt.title('분기별 남성캐주얼 상품 총 매출액 비교')
plt.savefig('분기별 남성캐주얼 상품 총 매출액 비교.png')
plt.show()

# %%
# 스포츠, 가공식품, 건강식품, 기타, 남성 캐주얼, 란제리/내의, 소형가구, 미용용품, 차/커피
# 분기별 란제리/내의 상품 총 매출액
lingerie = pd.pivot_table(data=buydata_df.query("중분류명 == '란제리/내의'"), values='구매금액', index='분기', columns='제휴사', aggfunc='sum')
lingerie
# Out:
# 제휴사               A          B       D
# 분기
# 2014_1분기  529848420  227519950  156700
# 2014_2분기  627396040  243926263  241220
# 2014_3분기  587820490  240860196  226100
# 2014_4분기  542861500  233667130  560410
# 2015_1분기  579968160  201815506  345600
# 2015_2분기  640636910  215411134  464100
# 2015_3분기  619833220  194171090  218660
# 2015_4분기  546777630  212464790  589900

# %%
#plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(10, 5))
sns.lineplot(data=lingerie)
#plt.xticks(rotation=45)
plt.title('분기별 란제리/내의 상품 총 매출액 비교')
plt.savefig('분기별 란제리&내의 총 매출액 비교.png')
plt.show()

# %%
# 스포츠, 가공식품, 건강식품, 기타, 남성캐주얼, 란제리/내의, 소형가구, 미용용품, 차/커피
# 분기별 미용용품 상품 총 매출액
makeup_prod = pd.pivot_table(data=buydata_df.query("중분류명 == '미용용품'"), values='구매금액', index='분기', columns='제휴사', aggfunc='sum')
makeup_prod
# Out:
# 제휴사               B          C        D
# 분기
# 2014_1분기  260816180  122629860   900700
# 2014_2분기  314474750   96775980  1570290
# 2014_3분기  341936030  111102510  1654390
# 2014_4분기  209749770   63718060  2363690
# 2015_1분기  241343210   58416360  3278660
# 2015_2분기  218256390   56626785  4440560
# 2015_3분기  234162750  133504411  5426960
# 2015_4분기  199456425  382818060  6990240

# %%
#plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(10, 5))
sns.lineplot(data=makeup_prod)
#plt.xticks(rotation=45)
plt.title('분기별 미용용품 총 매출액 비교')
plt.savefig('분기별 미용용품 총 매출액 비교.png')
plt.show()

# %%
# 스포츠, 가공식품, 건강식품, 기타, 남성캐주얼, 란제리/내의, 소형가구, 미용용품, 차/커피
# 분기별 차/커피 상품 총 매출액
tea = pd.pivot_table(data=buydata_df.query("중분류명 == '차/커피'"), values='구매금액', index='분기', columns='제휴사', aggfunc='sum')
tea
# Out:
# 제휴사               A          B           C        D
# 분기
# 2014_1분기  236165280  566313630   628805675  2493470
# 2014_2분기  228528580  753308640   673217644  2854280
# 2014_3분기  241050180  601444750   749714290  3556630
# 2014_4분기  299200680  597873830   659825996  5295820
# 2015_1분기  271252320  450288002   872740851  4820130
# 2015_2분기  243607950  456511294   827500981  6630810
# 2015_3분기  257259530  585284130  1085707911  6712600
# 2015_4분기  264524350  465535800   996157582  5850070

# %%
#plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(10, 5))
sns.lineplot(data=tea)
#plt.xticks(rotation=45)
plt.title('분기별 차/커피 총 매출액 비교')
plt.savefig('분기별 차&커피 총 매출액 비교.png')
plt.show()

# %%
# 분기별 대형가전 상품 총 매출액
big = pd.pivot_table(data=buydata_df.query("중분류명 == '대형가전'"), values='구매금액', index='분기', columns='제휴사', aggfunc='sum')
big
# Out:
# 제휴사                  A           B
# 분기
# 2014_1분기  1.510764e+09  41844000.0
# 2014_2분기  1.343603e+09  16627900.0
# 2014_3분기  1.465354e+09     47700.0
# 2014_4분기  1.809388e+09         NaN
# 2015_1분기  1.511179e+09         NaN
# 2015_2분기  1.582216e+09         NaN
# 2015_3분기  1.990257e+09         NaN
# 2015_4분기  2.451666e+09         NaN

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(10, 5))
sns.lineplot(data=big)
#plt.xticks(rotation=45)
plt.title('분기별 대형가전상품 총 매출액 비교')
#plt.savefig('분기별 대형가전상품 총 매출액 비교.png')
plt.show()

# %%
# 분기별 소형가전 상품 총 매출액
small = pd.pivot_table(data=buydata_df.query("중분류명 == '소형가전'"), values='구매금액', index='분기', columns='제휴사', aggfunc='sum')
small
# Out:
# 제휴사               A         B
# 분기
# 2014_1분기  222484280  29010790
# 2014_2분기  251974220   9863410
# 2014_3분기  253303540    572450
# 2014_4분기  193880280    177500
# 2015_1분기  215481540    611800
# 2015_2분기  327616530     29900
# 2015_3분기  273739700     36000
# 2015_4분기  329608820    174000

# %%
#plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(10, 5))
sns.lineplot(data=small)
#plt.xticks(rotation=45)
plt.title('분기별 소형가전상품 총 매출액 비교')
#plt.savefig('분기별 소형가전상품 총 매출액 비교.png')
plt.show()

# %% [markdown]
# C 제휴사에서 미용용품과 차/커피 상품이 B 제휴사와 비교해보았을 때 구매비율이 크게 높게 나왔다

# %%
buydata_df[buydata_df['제휴사'] == 'B'].query("중분류명 == '미용용품'")['소분류명'].unique()
# Out:
# array(['치약', '칫솔', '구강청결제', '샴푸', '내추럴샴푸', '미용소품', '일반샴푸단품', '프리미엄샴푸',
#        '모근/한방샴푸', '면도기', '면도보조용품', '새치용염색약', '칼라용염색약', '남성훼이셜케어', '치간칫솔',
#        '모발영양케어', '린스', '염색약', '헤어스타일링', '면도날', '메이크업브러쉬', '메탈', '분첩',
#        '헤어브러쉬/거울', '두피샴푸', '전동칫솔', '화장솜/면봉', '일반린스단품', '일반기획', '여행용품',
#        '헤어용품', '기타미용소품', '클렌징', '남성헤어케어', '용기', '온라인헤어스타일링', '온라인 헤어용품',
#        '남성바디케어', '남성용면도기', '미용대품', '전기면도기', '온라인일반헤어케어', '온라인기능헤어케어',
#        '온라인 구강용품'], dtype=object)

# %%
buydata_df[buydata_df['제휴사'] == 'C'].query("중분류명 == '미용용품'")['소분류명'].unique()
# Out:
# array(['염모제', '샴푸/린스세트', '치약', '칫솔', '샴푸', '린스/컨디셔너', '구강청정제', '기타구강관리용품',
#        '헤어에센스', '헤어스프레이', '트리트먼트/팩', '헤어무스/젤', '치약/칫솔세트', '헤어왁스',
#        '전동칫솔/칫솔모'], dtype=object)

# %%
buydata_df[buydata_df['제휴사'] == 'B'].query("중분류명 == '차/커피'")['소분류명'].unique()
# Out:
# array(['믹스커피', '생수', '한차', '액상차', '국내생수', '커피음료', '인스턴트커피', '티백차',
#        '과일/야채음료', '차혼합음료', '녹차', '건강미용차', '식수용차', '용기리필커피', '티백/드립 커피',
#        '탄산수', '과채혼합음료', '사이다', '콜라', '이온음료', '차음료', '커피선물세트', '수입생수',
#        '과일음료', '어린이음료', '혼합탄산', '비타민음료', '침출차', '스틱원두커피', '캡슐원두커피',
#        '수입과채혼합음료', '분말차', 'T-SHOP', '코코아', '비타/에너지음료', '원두커피',
#        '선물세트 과즙음료', '기능성음료', '아이스티', '혼합음료', '의약외품음료', '에너지음료', '기능성건강음료',
#        '허브', '수입커피/수입혼합차음료', '온라인과채음료', '분쇄원두커피', '커피크림', '아이스커피', '채소음료',
#        '홀빈원두커피', '유기농음료', '기능성음료선물세트', '수입탄산/이온음료', '차선물세트', '차 선물세트',
#        '온라인 탄산음료', '온라인커피차음료', '온라인 생수'], dtype=object)

# %%
buydata_df[buydata_df['제휴사'] == 'C'].query("중분류명 == '차/커피'")['소분류명'].unique()
# Out:
# array(['일반우유', '기능성우유', '가공우유', '크림/연유', '생수', '스틱원두커피', '믹스커피', '사이다',
#        '콜라', '혼합탄산', '과일음료', '과채음료세트', '커피음료', '일반차음료', '스포츠음료', '과실차',
#        '곡물/견과차', '비타민/에너지음료', '탄산수', '전통차음료', '녹차/홍차', '허브/꽃차', '전통/한방차',
#        '티백/드립원두커피', '채소음료', '파우치/즉석음료', '어린이음료', '컵커피차류', '식수용차', '코코아',
#        '용기/리필커피', '커피크리머', '아이스믹스커피', '아이스티', '차세트', '식이섬유음료', '숙취해소음료',
#        '캡슐원두커피', '분쇄/홀빈원두커피', '커피세트', '한방음료', '과채혼합음료', '기타기능성음료',
#        '무알콜맥주', '기능성음료세트'], dtype=object)

# %% [markdown]
# #### 제휴사 B 와 제휴사 C 의 미용용품 구매 고객 분석

# %%
# 제휴사 B 와 제휴사 C 의 미용용품 구매 고객 분석
market_B_beauty = buydata_df[buydata_df['제휴사'] == 'B'].query("중분류명 == '미용용품'")
market_C_beauty = buydata_df[buydata_df['제휴사'] == 'C'].query("중분류명 == '미용용품'")

# %%
# B 제휴사에서 2015년 4분기에 미용용품을 구매한 고객의 연령별 구매횟수
market_B_beauty[market_B_beauty['분기'] == '2015_4분기'].groupby('연령대')[['영수증번호']].count().sort_values(by='영수증번호', ascending=False)
# Out:
#          영수증번호
# 연령대
# 45세~49세   4935
# 40세~44세   4347
# 50세~54세   3478
# 35세~39세   3009
# 55세~59세   1758
# 30세~34세   1706
# 60세이상      974
# 25세~29세    567
# 20세~24세    156
# 19세이하        1

# %%
# C 제휴사에서 2015년 4분기에 미용용품을 구매한 고객의 연령별 구매횟수
market_C_beauty[market_C_beauty['분기'] == '2015_4분기'].groupby('연령대')[['영수증번호']].count().sort_values(by='영수증번호', ascending=False)
# Out:
#          영수증번호
# 연령대
# 45세~49세   2447
# 40세~44세   1926
# 50세~54세   1498
# 35세~39세   1107
# 55세~59세    677
# 30세~34세    560
# 60세이상      231
# 25세~29세    178
# 20세~24세    105
# 19세이하       13

# %%
# 제휴사 B 와 제휴사 C 의 차/커피 상품 구매 고객 분석
market_B_tea = buydata_df[buydata_df['제휴사'] == 'B'].query("중분류명 == '차/커피'")
market_C_tea = buydata_df[buydata_df['제휴사'] == 'C'].query("중분류명 == '차/커피'")

# %%
# B 제휴사에서 차/커피 상품을 구매한 고객의 연령별 구매횟수
market_B_tea.groupby('연령대')[['영수증번호']].count().sort_values(by='영수증번호', ascending=False)
# Out:
#           영수증번호
# 연령대
# 45세~49세  142341
# 40세~44세  135698
# 35세~39세  109681
# 50세~54세   82951
# 30세~34세   58139
# 55세~59세   43037
# 60세이상     30806
# 25세~29세   20631
# 20세~24세    5821
# 19세이하       451

# %%
# C 제휴사에서 2015년 4분기에 미용용품을 구매한 고객의 연령별 구매횟수
market_C_tea.groupby('연령대')[['영수증번호']].count().sort_values(by='영수증번호', ascending=False)
# Out:
#           영수증번호
# 연령대
# 40세~44세  265024
# 45세~49세  257104
# 35세~39세  193365
# 50세~54세  152743
# 30세~34세  119083
# 55세~59세   76697
# 60세이상     47797
# 25세~29세   37893
# 20세~24세   12815
# 19세이하       987

# %% [markdown]
# ### B 제휴사에서 다른 제휴사에 비해 잘 판매되었던 상품

# %%
print(len(buydata_df['중분류명'].unique()))
buydata_df['중분류명'].unique()
# Out:
# 62
# array(['일용잡화', '육류', '축산가공', '농산물', '수산품', '가공식품', '젓갈/반찬', '건강식품', '주류',
#        '차/커피', '섬유잡화', '액세서리', '화장품', '준보석/시계', '피혁잡화', '구두', '아동', '캐주얼',
#        '커리어', '트래디셔널', '시티웨어', '란제리/내의', '디자이너', '모피/피혁', '남성정장', '남성캐주얼',
#        '셔츠', '남성 트랜디', '스포츠', '골프용품', '대형가전', '통신/컴퓨터', '주방가전', '명품',
#        '주방용품', '생활잡화', '식기', '침구/수예', '식당', '미용용품', '행사', '여행용품', '전자/전기',
#        '문구/팬시', '수산물', '가구', '자동차용품', '보석', '소형가전', '교복', '기타', '반찬',
#        '선물', '기타의류', ' 생활잡화', '악기', '건강', '남성', '블라우스', '건강가전', '웨딩',
#        '오토바이용품'], dtype=object)

# %%
product_name = buydata_df['중분류명'].unique().tolist()
product_name

# %%
#import seaborn as sns
#import matplotlib.pyplot as plt

for product in product_name:
  df = pd.pivot_table(data=buydata_df.query(f"중분류명 == '{product}'"), values='구매금액', index='분기', columns='제휴사', aggfunc='sum')

plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(10, 5))
sns.lineplot(data=df)
plt.xticks(rotation=45)
plt.title(f'분기별 {product} 상품 총 매출액 비교')
#plt.savefig('분기별 스포츠 상품 총 매출액 비교.png')
plt.show()

# %%
plt.rc('font', family='NanumBarunGothic')

fig, axs = plt.subplots(figsize=(20,20), ncols = 2, nrows=5)
product_name = buydata_df['중분류명'].unique().tolist()

for i, product in enumerate(product_name):
    row = int(i/2)
    col = i%2

    sns.lineplot(data=df)
    plt.xticks(rotation=45)
    plt.tight_layout()
    axs[row,col].set_title(f'분기별 {product} 상품 총 매출액 비교')

plt.savefig('고객연령별_분기금액(전체데이터).png')
