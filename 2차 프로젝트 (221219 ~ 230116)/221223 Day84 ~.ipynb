# %% [markdown]
# #### customer_channel, buydata 테이블

# %%
# 고객 채널이용정보 CUSTOMER_CHANNEL (2015.10 ~ 2015.12)
#customer_channel = pd.read_excel('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/CUSTOMER_CHANNEL.xlsx')
customer_channel = pd.merge(custdemo_df, channel_df, on='고객번호', how='outer')
customer_channel = pd.merge(customer_channel, membership_df, on='고객번호', how='outer')
customer_channel.to_csv("/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/customer_channel.csv", index = False)

customer_channel_df = customer_channel.copy()
customer_channel_df

# %%
# 구매정보 BUYDATA
# prodpur_df : 제휴사, 영수증번호, 소분류코드, 고객번호, 구매일자, 구매시간, 구매금액
# custdemo_df : 고객번호, 성별, 연령대
# prodcl_df : 중분류명, 소분류명

a = prodpur_df.drop(columns=['대분류코드', '중분류코드'])
b = custdemo_df.iloc[:, :3]
c = prodcl_df.iloc[:, 4:]

d = pd.merge(a, b, on='고객번호', how='outer')
buydata = pd.merge(d, c, on='소분류코드', how='outer')
buydata.to_csv("/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/buydata.csv", index = False)

buydata[:5]

# %%
buydata_df = buydata.copy()
buydata_df

# %% [markdown]
# # 데이터 불러오기

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# ...

# %%
import numpy as np
import pandas as pd

# %%
# 경쟁사이용 COMPET
#compet = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/경쟁사이용 (COMPET).txt', encoding='cp949')

# 멤버쉽여부 MEMBERSHIP
#membership = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/멤버십여부 (MEMBERSHIP).txt', encoding='cp949')

# 채널이용 CHANNEL
#channel = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/채널이용 (CHANNEL).txt', encoding='cp949')

# 고객DEMO(정보) CUSTDEMO
#custdemo = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/고객DEMO (CUSTDEMO).txt', encoding='cp949')

# 상품분류 PRODCL
#prodcl = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/상품분류 (PRODCL).txt', encoding='cp949')
#prodcl = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/product (중분류명 수정).csv')

# 구매상품 PRODPUR
#prodpur = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/구매상품TR (PRODPUR).txt', encoding='cp949')

# 고객 채널이용정보 CUSTOMER_CHANNEL (2015.10 ~ 2015.12)
#customer_channel = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/customer_channel.csv')

# 구매정보 BUYDATA
#buydata = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/buydata.csv')
buydata = pd.read_csv('/content/drive/MyDrive/2차 프로젝트 (221219 ~ 230116)/L members data/purchase5.csv')

# %%
#compet.sort_values(by = '고객번호', inplace=True, ignore_index=True)

'''
membership.sort_values(by = '고객번호', inplace=True, ignore_index=True)
channel.sort_values(by = '고객번호', inplace=True, ignore_index=True)
custdemo.sort_values(by = '고객번호', inplace=True, ignore_index=True)
prodpur.sort_values(by = '고객번호', inplace=True, ignore_index=True)
'''
# Out:
# "\nmembership.sort_values(by = '고객번호', inplace=True, ignore_index=True)\nchannel.sort_values(by = '고객번호', inplace=True, ignore_index=True)\ncustdemo.sort_values(by = '고객번호', inplace=True, ignore_index=True)\nprodpur.sort_values(by = '고객번호', inplace=True, ignore_index=True)\n"

# %%
# 원본 데이터 copy
#compet_df = compet.copy()
#customer_channel_df = customer_channel.copy()
buydata_df = buydata.iloc[:, 1:]

'''
membership_df = membership.copy()
channel_df = channel.copy()
custdemo_df = custdemo.copy()
prodcl_df = prodcl.copy()
prodpur_df = prodpur.copy()
'''
# Out:
# '\nmembership_df = membership.copy()\nchannel_df = channel.copy()\ncustdemo_df = custdemo.copy()\nprodcl_df = prodcl.copy()\nprodpur_df = prodpur.copy()\n'

# %%
buydata_df[:5]
# Out:
#    고객번호 성별    연령대       거주지역 제휴사  중분류명  소분류명    영수증번호  점포코드      구매일자  구매시간  \
# 0     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  1456379    12  20140228    15
# 1     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  2751160    12  20140919    15
# 2     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  1307657    12  20140130    11
# 3     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  3960475    12  20150327    12
# 4     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  5602223    12  20151130    17
#
#     구매금액
# 0   9500
# 1   5000
# 2  19810
# 3   1000
# 4   6800

# %%
buydata_df.shape
# Out:
# (28593030, 12)

# %%
buydata_df.isna().sum()
# Out:
# 고객번호     0
# 성별       0
# 연령대      0
# 거주지역     0
# 제휴사      0
# 중분류명     0
# 소분류명     0
# 영수증번호    0
# 점포코드     0
# 구매일자     0
# 구매시간     0
# 구매금액     0
# dtype: int64

# %%
len(buydata_df['점포코드'].unique())
# Out:
# 593

# %% [markdown]
# # 데이터 탐색(1) : 제휴사 A

# %%
market_A = buydata_df.query("제휴사 == 'A'")

# %%
market_A['분기'] = np.where(market_A['구매일자'] < 20140401, '2014_1분기',
                          np.where(market_A['구매일자'] < 20140701, '2014_2분기',
                                   np.where(market_A['구매일자'] < 20141001, '2014_3분기',
                                            np.where(market_A['구매일자'] < 20150101, '2014_4분기',
                                                     np.where(market_A['구매일자'] < 20150401, '2015_1분기',
                                                              np.where(market_A['구매일자'] < 20150701, '2015_2분기',
                                                                       np.where(market_A['구매일자'] < 20151001, '2015_3분기','2015_4분기')))))))

market_A[:5]
# Out:
# <ipython-input-7-8f93c15c17a4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   market_A['분기'] = np.where(market_A['구매일자'] < 20140401, '2014_1분기',
#    고객번호 성별    연령대       거주지역 제휴사  중분류명  소분류명    영수증번호  점포코드      구매일자  구매시간  \
# 0     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  1456379    12  20140228    15
# 1     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  2751160    12  20140919    15
# 2     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  1307657    12  20140130    11
# 3     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  3960475    12  20150327    12
# 4     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  5602223    12  20151130    17
#
#     구매금액        분기
# 0   9500  2014_1분기
# 1   5000  2014_3분기
# 2  19810  2014_1분기
# 3   1000  2015_1분기
# 4   6800  2015_4분기

# %%
market_A['구매일자_년도'] = market_A['구매일자'].astype('string').str[:4]
# Out:
# <ipython-input-8-b79395f8644f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   market_A['구매일자_년도'] = market_A['구매일자'].astype('string').str[:4]

# %% [markdown]
# ## 각 점포의 분기별 매출 (3개월 단위)

# %%
q = market_A.groupby(['점포코드', '분기'], as_index=False)[['구매금액']].sum()
q
# Out:
#      점포코드        분기        구매금액
# 0       1  2014_1분기  5508189310
# 1       1  2014_2분기  6219293390
# 2       1  2014_3분기  5232499000
# 3       1  2014_4분기  7687667440
# 4       1  2015_1분기  5859543670
# ..    ...       ...         ...
# 361    49  2015_3분기    29620870
# 362    49  2015_4분기    65190150
# 363    50  2015_3분기    40633620
# 364    50  2015_4분기    99304000
# 365    51  2015_4분기      433000
#
# [366 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(30, 20))

for i in range(1, 52):
  plt.subplot(13, 4, i)
  plt.plot(q.query(f"점포코드 == {i}")['분기'], q.query(f"점포코드 == {i}")['구매금액'])
  plt.title(f'점포코드 {i}')
  plt.xlabel('분기')
  plt.ylabel('매출')

  plt.tight_layout()

# %% [markdown]
# ## 고객의 연령별 분기 구입금액

# %%
market_A
# Out:
#            고객번호 성별      연령대       거주지역 제휴사  중분류명    소분류명    영수증번호  점포코드  \
# 0             1  M    60세이상  서울특별시 강남구   A  일용잡화    위생세제  1456379    12
# 1             1  M    60세이상  서울특별시 강남구   A  일용잡화    위생세제  2751160    12
# 2             1  M    60세이상  서울특별시 강남구   A  일용잡화    위생세제  1307657    12
# 3             1  M    60세이상  서울특별시 강남구   A  일용잡화    위생세제  3960475    12
# 4             1  M    60세이상  서울특별시 강남구   A  일용잡화    위생세제  5602223    12
# ...         ... ..      ...        ...  ..   ...     ...      ...   ...
# 28592783  19383  F  25세~29세   경상남도 함양군   A   캐주얼   영스트리트  4813386    16
# 28592784  19383  F  25세~29세   경상남도 함양군   A   캐주얼   영스트리트  5090339    16
# 28592785  19383  F  25세~29세   경상남도 함양군   A    셔츠   비지니스군  5162132    16
# 28592786  19383  F  25세~29세   경상남도 함양군   A   스포츠    스포츠화  5743419    25
# 28592787  19383  F  25세~29세   경상남도 함양군   A   스포츠  아디다스의류  5114971    47
#
#               구매일자  구매시간   구매금액        분기
# 0         20140228    15   9500  2014_1분기
# ...

# %%
age_q = market_A.groupby(['연령대', '분기'], as_index=False)[['구매금액']].sum()
age_q
# Out:
#       연령대        분기        구매금액
# 0   19세이하  2014_1분기     2736320
# 1   19세이하  2014_2분기     3705340
# 2   19세이하  2014_3분기     8050740
# 3   19세이하  2014_4분기    12313570
# 4   19세이하  2015_1분기     4357980
# ..    ...       ...         ...
# 75  60세이상  2014_4분기  7725611130
# 76  60세이상  2015_1분기  6179135630
# 77  60세이상  2015_2분기  6478161340
# 78  60세이상  2015_3분기  5774289580
# 79  60세이상  2015_4분기  7897225890
#
# [80 rows x 3 columns]

# %%
age_q['연령대'].unique()[1]
# Out:
# '20세~24세'

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# 고객의 연령별 분기 구매금액
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

fig, axs = plt.subplots(figsize=(20,20), ncols = 2, nrows=5)
lm_features = ['19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상']

for i, feature in enumerate(lm_features):
    row = int(i/2)
    col = i%2
    # ax(축) 자리 지정
    sns.barplot(data = age_q[age_q['연령대'] == f'{feature}'], x='분기', y='구매금액', ax = axs[row][col]) 
    plt.tight_layout()
    axs[row,col].set_title(f'{feature} 분기별 구매금액')

plt.savefig('고객연령별_분기금액.png')

# %% [markdown]
# #### * 분기별 구매금액이 높은 고객의 연령

# %%
age_q['분기'].unique()
# Out:
# array(['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기', '2015_1분기',
#        '2015_2분기', '2015_3분기', '2015_4분기'], dtype=object)

# %%
# 분기별 고객 연령대별 구매금액
#import seaborn as sns

fig, axs = plt.subplots(figsize=(20,20), ncols = 2, nrows=4)
lm_features = ['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기',
               '2015_1분기', '2015_2분기', '2015_3분기', '2015_4분기']

for i, feature in enumerate(lm_features):
    row = int(i/2)
    col = i%2
    # ax(축) 자리 지정
    sns.barplot(data = age_q[age_q['분기'] == f'{feature}'], x='연령대', y='구매금액', ax = axs[row][col]) 
    plt.tight_layout()
    axs[row,col].set_title(f'{feature} 연령대별 구매금액')

#plt.savefig('분기별_고객연령별_구매금액.png')

# %% [markdown]
# 연말, 연초가 있는 2014년 4분기부터 2015년 1분기에 매출이 높게 나타났던 것으로 보이고,\
# 주로 30대 후반 ~ 50대 초중반 연령이 구매를 많이 하는 것으로 보인다

# %% [markdown]
# ## 연령별로 분기별 인기있는 점포 번호

# %%
market_A
# Out:
#            고객번호 성별      연령대       거주지역 제휴사  중분류명    소분류명    영수증번호  점포코드  \
# 0             1  M    60세이상  서울특별시 강남구   A  일용잡화    위생세제  1456379    12
# 1             1  M    60세이상  서울특별시 강남구   A  일용잡화    위생세제  2751160    12
# 2             1  M    60세이상  서울특별시 강남구   A  일용잡화    위생세제  1307657    12
# 3             1  M    60세이상  서울특별시 강남구   A  일용잡화    위생세제  3960475    12
# 4             1  M    60세이상  서울특별시 강남구   A  일용잡화    위생세제  5602223    12
# ...         ... ..      ...        ...  ..   ...     ...      ...   ...
# 28592783  19383  F  25세~29세   경상남도 함양군   A   캐주얼   영스트리트  4813386    16
# 28592784  19383  F  25세~29세   경상남도 함양군   A   캐주얼   영스트리트  5090339    16
# 28592785  19383  F  25세~29세   경상남도 함양군   A    셔츠   비지니스군  5162132    16
# 28592786  19383  F  25세~29세   경상남도 함양군   A   스포츠    스포츠화  5743419    25
# 28592787  19383  F  25세~29세   경상남도 함양군   A   스포츠  아디다스의류  5114971    47
#
#               구매일자  구매시간   구매금액        분기
# 0         20140228    15   9500  2014_1분기
# ...

# %%
# 연령대별, 분기별, 점포코드 별 총 구매금액
a = market_A.groupby(['연령대', '분기', '점포코드'], as_index=False)[['구매금액']].sum()

# %%
a.query("연령대 == '19세이하' & 분기 == '2014_1분기'").sort_values(by='구매금액', ascending=False)
# Out:
#       연령대        분기  점포코드    구매금액
# 11  19세이하  2014_1분기    30  610940
# 2   19세이하  2014_1분기     5  590680
# 10  19세이하  2014_1분기    29  312000
# 1   19세이하  2014_1분기     4  290600
# 7   19세이하  2014_1분기    19  273100
# 9   19세이하  2014_1분기    27  219300
# 5   19세이하  2014_1분기    16  208600
# 8   19세이하  2014_1분기    23  139800
# 0   19세이하  2014_1분기     2   45000
# 4   19세이하  2014_1분기    12   26500
# 3   19세이하  2014_1분기     8   14800
# 6   19세이하  2014_1분기    18    5000

# %%
x = a.query("연령대 == '19세이하' & 분기 == '2014_3분기'").sort_values(by='구매금액', ascending=False)[:1].index
x
# Out:
# Int64Index([24], dtype='int64')

# %%
x[0]
# Out:
# 24

# %%
age_lst = ['19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상']
quarter_lst = ['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기', '2015_1분기', '2015_2분기', '2015_3분기', '2015_4분기']
top_index_lst = []

for age in age_lst:
  for quarter in quarter_lst:
    indx = a.query(f"연령대 == '{age}' & 분기 == '{quarter}'").sort_values(by='구매금액', ascending=False)[:1].index
    top_index_lst.append(indx[0])

top_index_lst

# %%
# 연령별 분기별 인기있는 점포번호
age_quarter_store = a.iloc[top_index_lst]
age_quarter_store = age_quarter_store.reset_index().iloc[:, 1:]
age_quarter_store
# Out:
#       연령대        분기  점포코드        구매금액
# 0   19세이하  2014_1분기    30      610940
# 1   19세이하  2014_2분기    16     1459900
# 2   19세이하  2014_3분기    16     3789500
# 3   19세이하  2014_4분기    16     7709900
# 4   19세이하  2015_1분기    16      841500
# ..    ...       ...   ...         ...
# 75  60세이상  2014_4분기     2  1503104820
# 76  60세이상  2015_1분기     2  1127422410
# 77  60세이상  2015_2분기     2  1105551870
# 78  60세이상  2015_3분기     2  1132975520
# 79  60세이상  2015_4분기     2  1482044910
#
# [80 rows x 4 columns]

# %%
age_quarter_store['점포코드'].unique()
# Out:
# array([30, 16, 18,  5, 29, 24,  1,  2,  4, 37])

# %%
import plotly.express as px

fig = px.bar(age_quarter_store, x='분기', y='구매금액',
             color='연령대', text="점포코드", barmode='group', height=400,
             title='연령별 분기별 인기있는 점포번호')
fig.update_traces(textfont_size=15, textangle=0, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 성별 분기별 인기있는 점포 번호

# %%
# 성별, 분기별, 점포코드 별 총 구매금액
b = market_A.groupby(['성별', '분기', '점포코드'], as_index=False)[['구매금액']].sum()
b
# Out:
#     성별        분기  점포코드        구매금액
# 0    F  2014_1분기     1  4329361050
# 1    F  2014_1분기     2  6701850150
# 2    F  2014_1분기     3  1309114930
# 3    F  2014_1분기     4  3058089080
# 4    F  2014_1분기     5   376712920
# ..  ..       ...   ...         ...
# 726  M  2015_4분기    46    19632820
# 727  M  2015_4분기    47   109215160
# 728  M  2015_4분기    48     2919480
# 729  M  2015_4분기    49    13241280
# 730  M  2015_4분기    50    14636380
#
# [731 rows x 4 columns]

# %%
gender_lst = ['F', 'M']
quarter_lst = ['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기', '2015_1분기', '2015_2분기', '2015_3분기', '2015_4분기']
top_index_lst = []

for gender in gender_lst:
  for quarter in quarter_lst:
    indx = b.query(f"성별 == '{gender}' & 분기 == '{quarter}'").sort_values(by='구매금액', ascending=False)[:1].index
    top_index_lst.append(indx[0])

top_index_lst
# Out:
# [1, 42, 83, 124, 171, 218, 266, 316, 367, 408, 449, 489, 537, 583, 632, 681]

# %%
# 성별 분기별 인기있는 점포번호
gender_quarter_store = b.iloc[top_index_lst]
gender_quarter_store = gender_quarter_store.reset_index().iloc[:, 1:]
gender_quarter_store
# Out:
#    성별        분기  점포코드        구매금액
# 0   F  2014_1분기     2  6701850150
# 1   F  2014_2분기     2  6898758840
# 2   F  2014_3분기     2  6290474580
# 3   F  2014_4분기     2  7374848870
# 4   F  2015_1분기     2  6184123290
# 5   F  2015_2분기     2  6703257700
# 6   F  2015_3분기     2  6148888220
# 7   F  2015_4분기     2  8195015510
# 8   M  2014_1분기     2  1253987070
# 9   M  2014_2분기     2  1589387750
# 10  M  2014_3분기     2  1327312710
# 11  M  2014_4분기     1  2299230340
# 12  M  2015_1분기     2  1738176910
# 13  M  2015_2분기     1  1861171360
# 14  M  2015_3분기     2  1624490090
# 15  M  2015_4분기     1  2050955800

# %%
import plotly.express as px

fig = px.bar(gender_quarter_store, x='분기', y='구매금액',
             color='성별', text="점포코드", barmode='group', height=400,
             title='성별 분기별 인기있는 점포번호')
fig.update_traces(textfont_size=15, textangle=0, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 연령별 분기별 인기있는 구입 상품

# %%
# 연령대별, 분기별, 인기 구매 상품
c = market_A.groupby(['연령대', '분기', '중분류명'], as_index=False)[['소분류명']].count().rename(columns={'소분류명' : '구매횟수'})
c
# Out:
#         연령대        분기    중분류명  구매횟수
# 0     19세이하  2014_1분기    가공식품    25
# 1     19세이하  2014_1분기      구두     1
# 2     19세이하  2014_1분기     농산물     8
# 3     19세이하  2014_1분기  란제리/내의     1
# 4     19세이하  2014_1분기    섬유잡화     3
# ...     ...       ...     ...   ...
# 3423  60세이상  2015_4분기     커리어   766
# 3424  60세이상  2015_4분기  통신/컴퓨터    63
# 3425  60세이상  2015_4분기   트래디셔널   523
# 3426  60세이상  2015_4분기    피혁잡화   217
# 3427  60세이상  2015_4분기     화장품  2436
#
# [3428 rows x 4 columns]

# %%
age_lst = ['19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상']
quarter_lst = ['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기', '2015_1분기', '2015_2분기', '2015_3분기', '2015_4분기']
top_index_lst = []

for age in age_lst:
  for quarter in quarter_lst:
    indx = c.query(f"연령대 == '{age}' & 분기 == '{quarter}'").sort_values(by='구매횟수', ascending=False)[:1].index
    top_index_lst.append(indx[0])

top_index_lst

# %%
# 연령별 분기별 인기 구매 상품
age_quarter_product = c.iloc[top_index_lst]
age_quarter_product = age_quarter_product.reset_index().iloc[:, 1:]
age_quarter_product
# Out:
#       연령대        분기  중분류명   구매횟수
# 0   19세이하  2014_1분기  가공식품     25
# 1   19세이하  2014_2분기  가공식품     44
# 2   19세이하  2014_3분기  가공식품     41
# 3   19세이하  2014_4분기  가공식품     39
# 4   19세이하  2015_1분기  가공식품     24
# ..    ...       ...   ...    ...
# 75  60세이상  2014_4분기  가공식품  13434
# 76  60세이상  2015_1분기  가공식품  13264
# 77  60세이상  2015_2분기   농산물  13782
# 78  60세이상  2015_3분기  가공식품  13856
# 79  60세이상  2015_4분기  가공식품  13491
#
# [80 rows x 4 columns]

# %%
age_quarter_product['중분류명'].unique()
# Out:
# array(['가공식품', '농산물'], dtype=object)

# %%
import plotly.express as px

fig = px.bar(age_quarter_product, x='분기', y='구매횟수',
             color='연령대', text="중분류명", barmode='group', height=400,
             title="연령별 분기별 인기 구매 상품")
fig.update_traces(textfont_size=15, textangle=90, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

fig = px.bar(age_quarter_product, x='연령대', y='구매횟수',
             color='분기', text="중분류명", barmode='group', height=400,
             title="연령별 분기별 인기 구매 상품")
fig.update_traces(textfont_size=15, textangle=90, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 연령별 분기별 인기있는 구입 상품 (소분류명으로 분류)

# %%
# 연령별 분기별 인기있는 구입 상품 (소분류명)
g = market_A.groupby(['연령대', '분기', '소분류명'])[['소분류명']].count().rename(columns={'소분류명' : '구매횟수'})
g = g.reset_index()
g
# Out:
#          연령대        분기      소분류명  구매횟수
# 0      19세이하  2014_1분기  L/C 아웃도어     1
# 1      19세이하  2014_1분기     NB 여화     1
# 2      19세이하  2014_1분기       건생선     1
# 3      19세이하  2014_1분기        곡물     1
# 4      19세이하  2014_1분기    기초 화장품     2
# ...      ...       ...       ...   ...
# 28317  60세이상  2015_4분기      휠라골프    33
# 28318  60세이상  2015_4분기    휠라아웃도어     1
# 28319  60세이상  2015_4분기      휴고보스     2
# 28320  60세이상  2015_4분기       휴지류     8
# 28321  60세이상  2015_4분기      힐앤토트     3
#
# [28322 rows x 4 columns]

# %%
g.query("연령대 == '30세~34세' & 분기 == '2014_1분기'").sort_values(by='구매횟수', ascending=False)[:1]
# Out:
#           연령대        분기 소분류명  구매횟수
# 5554  30세~34세  2014_1분기  유제품  1872

# %%
age_lst = ['19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상']
quarter_lst = ['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기', '2015_1분기', '2015_2분기', '2015_3분기', '2015_4분기']
top_index_lst = []

for age in age_lst:
  for quarter in quarter_lst:
    indx = g.query(f"연령대 == '{age}' & 분기 == '{quarter}'").sort_values(by='구매횟수', ascending=False)[:1].index
    top_index_lst.append(indx[0])

top_index_lst

# %%
# 연령별 분기별 인기있는 구입 상품 (소분류명)
age_quarter_small_product = g.iloc[top_index_lst]
age_quarter_small_product = age_quarter_small_product.reset_index().iloc[:, 1:]
age_quarter_small_product
# Out:
#       연령대        분기        소분류명  구매횟수
# 0   19세이하  2014_1분기        수입식품     8
# 1   19세이하  2014_2분기    지방스넥(부대)    12
# 2   19세이하  2014_3분기    L/C 아웃도어     9
# 3   19세이하  2014_4분기    L/C 아웃도어    18
# 4   19세이하  2015_1분기  global SPA     7
# ..    ...       ...         ...   ...
# 75  60세이상  2014_4분기          청과  3340
# 76  60세이상  2015_1분기          채소  3268
# 77  60세이상  2015_2분기          청과  3902
# 78  60세이상  2015_3분기       유기농채소  3196
# 79  60세이상  2015_4분기       유기농채소  3102
#
# [80 rows x 4 columns]

# %%
age_quarter_small_product['소분류명'].unique()
# Out:
# array(['수입식품', '지방스넥(부대)', 'L/C 아웃도어', 'global SPA', '청과', '유제품', '서양델리',
#        '일식델리', '원두커피', '브랜드샵', '기초 화장품', '채소', '유기농채소'], dtype=object)

# %%
import plotly.express as px

fig = px.bar(age_quarter_small_product.query("분기 in ['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기']"),
             x='연령대', y='구매횟수', color='분기', text="소분류명", barmode='group', height=400,
             title='연령별 2014년도 분기별 인기있는 구입 상품 (소분류명으로 분류)')
fig.update_traces(textfont_size=40, textangle=90, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# '19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상'
import plotly.express as px

fig = px.bar(age_quarter_small_product.query("분기 in ['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기'] & 연령대 in ['19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세']"),
             x='연령대', y='구매횟수', color='분기', text="소분류명", barmode='group', height=400,
             title='10~30대 2014년도 분기별 인기있는 구입 상품 (소분류명으로 분류)')
fig.update_traces(textfont_size=40, textangle=90, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# '19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상'
import plotly.express as px

fig = px.bar(age_quarter_small_product.query("분기 in ['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기'] & 연령대 in ['40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상']"),
             x='연령대', y='구매횟수', color='분기', text="소분류명", barmode='group', height=400,
             title='40대 이상 2014년도 분기별 인기있는 구입 상품 (소분류명으로 분류)')
fig.update_traces(textfont_size=15, textangle=90, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

fig = px.bar(age_quarter_small_product.query("분기 in ['2015_1분기', '2015_2분기', '2015_3분기', '2015_4분기']"),
             x='연령대', y='구매횟수', color='분기', text="소분류명", barmode='group', height=400,
             title='연령별 2015년도 분기별 인기있는 구입 상품 (소분류명으로 분류)')
fig.update_traces(textfont_size=40, textangle=90, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# '19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상'
import plotly.express as px

fig = px.bar(age_quarter_small_product.query("분기 in ['2015_1분기', '2015_2분기', '2015_3분기', '2015_4분기'] & 연령대 in ['19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세']"),
             x='연령대', y='구매횟수', color='분기', text="소분류명", barmode='group', height=400,
             title='10~30대 2015년도 분기별 인기있는 구입 상품 (소분류명으로 분류)')
fig.update_traces(textfont_size=40, textangle=90, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# '19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상'
import plotly.express as px

fig = px.bar(age_quarter_small_product.query("분기 in ['2015_1분기', '2015_2분기', '2015_3분기', '2015_4분기'] & 연령대 in ['40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상']"),
             x='연령대', y='구매횟수', color='분기', text="소분류명", barmode='group', height=400,
             title='40대 이상 2015년도 분기별 인기있는 구입 상품 (소분류명으로 분류)')
fig.update_traces(textfont_size=15, textangle=90, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 성별 분기별 인기있는 구입 상품

# %%
# 성별, 분기별 인기있는 구입 상품
d = market_A.groupby(['성별', '분기', '중분류명'], as_index=False)[['소분류명']].count().rename(columns={'소분류명' : '구매횟수'})
d
# Out:
#     성별        분기    중분류명    구매횟수
# 0    F  2014_1분기    가공식품  115540
# 1    F  2014_1분기      가구     625
# 2    F  2014_1분기    건강식품    4998
# 3    F  2014_1분기    골프용품    5208
# 4    F  2014_1분기      교복     186
# ..  ..       ...     ...     ...
# 738  M  2015_4분기     커리어     802
# 739  M  2015_4분기  통신/컴퓨터     266
# 740  M  2015_4분기   트래디셔널    1316
# 741  M  2015_4분기    피혁잡화     572
# 742  M  2015_4분기     화장품    4916
#
# [743 rows x 4 columns]

# %%
gender_lst = ['F', 'M']
quarter_lst = ['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기', '2015_1분기', '2015_2분기', '2015_3분기', '2015_4분기']
top_index_lst = []

for gender in gender_lst:
  for quarter in quarter_lst:
    indx = d.query(f"성별 == '{gender}' & 분기 == '{quarter}'").sort_values(by='구매횟수', ascending=False)[:1].index
    top_index_lst.append(indx[0])

top_index_lst
# Out:
# [0, 46, 92, 139, 185, 232, 280, 327, 374, 420, 466, 511, 557, 604, 650, 696]

# %%
# 성별, 분기별 인기있는 구입 상품
gender_quarter_product = d.iloc[top_index_lst]
gender_quarter_product = gender_quarter_product.reset_index().iloc[:, 1:]
gender_quarter_product
# Out:
#    성별        분기  중분류명    구매횟수
# 0   F  2014_1분기  가공식품  115540
# 1   F  2014_2분기  가공식품  124319
# 2   F  2014_3분기  가공식품  130115
# 3   F  2014_4분기  가공식품  136478
# 4   F  2015_1분기  가공식품  134533
# 5   F  2015_2분기  가공식품  134314
# 6   F  2015_3분기  가공식품  137312
# 7   F  2015_4분기  가공식품  133930
# 8   M  2014_1분기  가공식품   23576
# 9   M  2014_2분기  가공식품   25708
# 10  M  2014_3분기  가공식품   26553
# 11  M  2014_4분기  가공식품   27876
# 12  M  2015_1분기  가공식품   27744
# 13  M  2015_2분기  가공식품   27547
# 14  M  2015_3분기  가공식품   27969
# 15  M  2015_4분기  가공식품   27201

# %%
gender_quarter_product['중분류명'].unique()
# Out:
# array(['가공식품'], dtype=object)

# %%
import plotly.express as px

fig = px.bar(gender_quarter_product, x='분기', y='구매횟수',
             color='성별', text="중분류명", barmode='group', height=400,
             title='성별 분기별 인기있는 구입 상품')
fig.update_traces(textfont_size=15, textangle=0, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 성별 분기별 인기있는 구입 상품 (소분류명으로 분류)

# %%
# 성별, 분기별 인기있는 구입 상품 (소분류명)
e = market_A.groupby(['성별', '분기', '소분류명'])[['소분류명']].count().rename(columns={'소분류명' : '구매횟수'})
e = e.reset_index()
e
# Out:
#      성별        분기            소분류명  구매횟수
# 0     F  2014_1분기             14K   606
# 1     F  2014_1분기          4대 B/D   925
# 2     F  2014_1분기  ACC Bloom (1F)     9
# 3     F  2014_1분기  ACC Bloom (3F)   169
# 4     F  2014_1분기          ARCHIV     7
# ...  ..       ...             ...   ...
# 7046  M  2015_4분기          휠라아웃도어     4
# 7047  M  2015_4분기            휴고보스     5
# 7048  M  2015_4분기          휴고보스골프     2
# 7049  M  2015_4분기             휴지류    13
# 7050  M  2015_4분기            힐앤토트    12
#
# [7051 rows x 4 columns]

# %%
gender_lst = ['F', 'M']
quarter_lst = ['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기', '2015_1분기', '2015_2분기', '2015_3분기', '2015_4분기']
top_index_lst = []

for gender in gender_lst:
  for quarter in quarter_lst:
    indx = e.query(f"성별 == '{gender}' & 분기 == '{quarter}'").sort_values(by='구매횟수', ascending=False)[:1].index
    top_index_lst.append(indx[0])

top_index_lst
# Out:
# [349,
#  764,
#  1138,
#  1568,
#  1999,
#  2476,
#  2939,
#  3489,
#  3975,
#  4369,
#  4723,
#  5126,
#  5572,
#  5981,
#  6400,
#  6909]

# %%
# 성별, 분기별 인기있는 구입 상품
gender_quarter_small_product = e.iloc[top_index_lst]
gender_quarter_small_product = gender_quarter_small_product.reset_index().iloc[:, 1:]
gender_quarter_small_product
# Out:
#    성별        분기 소분류명   구매횟수
# 0   F  2014_1분기   청과  21942
# 1   F  2014_2분기   청과  26261
# 2   F  2014_3분기  유제품  23043
# 3   F  2014_4분기  유제품  22040
# 4   F  2015_1분기  유제품  22385
# 5   F  2015_2분기   청과  26226
# 6   F  2015_3분기  유제품  21732
# 7   F  2015_4분기  유제품  20591
# 8   M  2014_1분기   청과   4338
# 9   M  2014_2분기   청과   5289
# 10  M  2014_3분기  유제품   4647
# 11  M  2014_4분기  유제품   4606
# 12  M  2015_1분기   청과   4647
# 13  M  2015_2분기   청과   5357
# 14  M  2015_3분기  유제품   4408
# 15  M  2015_4분기  유제품   4233

# %%
gender_quarter_small_product['소분류명'].unique()
# Out:
# array(['청과', '유제품'], dtype=object)

# %%
import plotly.express as px

fig = px.bar(gender_quarter_small_product, x='분기', y='구매횟수',
             color='성별', text="소분류명", barmode='group', height=400,
             title='성별 분기별 인기있는 구입 상품 (소분류명으로 분류)')
fig.update_traces(textfont_size=15, textangle=0, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 지역별 연령 분포 (top 10)

# %%
market_A
# Out:
#            고객번호 성별      연령대       거주지역 제휴사  중분류명    소분류명    영수증번호  점포코드  \
# 0             1  M    60세이상  서울특별시 강남구   A  일용잡화    위생세제  1456379    12
# 1             1  M    60세이상  서울특별시 강남구   A  일용잡화    위생세제  2751160    12
# 2             1  M    60세이상  서울특별시 강남구   A  일용잡화    위생세제  1307657    12
# 3             1  M    60세이상  서울특별시 강남구   A  일용잡화    위생세제  3960475    12
# 4             1  M    60세이상  서울특별시 강남구   A  일용잡화    위생세제  5602223    12
# ...         ... ..      ...        ...  ..   ...     ...      ...   ...
# 28592783  19383  F  25세~29세   경상남도 함양군   A   캐주얼   영스트리트  4813386    16
# 28592784  19383  F  25세~29세   경상남도 함양군   A   캐주얼   영스트리트  5090339    16
# 28592785  19383  F  25세~29세   경상남도 함양군   A    셔츠   비지니스군  5162132    16
# 28592786  19383  F  25세~29세   경상남도 함양군   A   스포츠    스포츠화  5743419    25
# 28592787  19383  F  25세~29세   경상남도 함양군   A   스포츠  아디다스의류  5114971    47
#
#               구매일자  구매시간   구매금액        분기
# 0         20140228    15   9500  2014_1분기
# ...

# %%
f = market_A.groupby(['연령대', '거주지역'])[['거주지역']].count().rename(columns={'거주지역' : '분포'})
f = f.reset_index()
f
# Out:
#        연령대          거주지역     분포
# 0    19세이하       경기도 김포시     27
# 1    19세이하      경상남도 함양군    276
# 2    19세이하      광주광역시 북구     38
# 3    19세이하     부산광역시 기장군     54
# 4    19세이하     서울특별시 강남구     16
# ..     ...           ...    ...
# 374  60세이상      전라남도 영광군    592
# 375  60세이상      전라북도 군산시   3753
# 376  60세이상          정보없음  10912
# 377  60세이상  충청남도 천안시 동남구   1023
# 378  60세이상      충청북도 단양군    117
#
# [379 rows x 3 columns]

# %%
s = f.query("연령대 == '19세이하'").sort_values(by='분포', ascending=False)[:10].index
s
# Out:
# Int64Index([5, 1, 8, 3, 2, 0, 9, 7, 4, 6], dtype='int64')

# %%
age_lst = ['19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상']
top_index_lst = []

for age in age_lst:
  indx = f.query(f"연령대 == '{age}'").sort_values(by='분포', ascending=False)[:10].index
  for i in range(10):
    top_index_lst.append(indx[i])

top_index_lst

# %%
# 지역별 연령 분포
area_age_top10 = f.iloc[top_index_lst]
area_age_top10 = area_age_top10.reset_index().iloc[:, 1:]
area_age_top10
# Out:
#       연령대        거주지역     분포
# 0   19세이하   서울특별시 관악구    515
# 1   19세이하    경상남도 함양군    276
# 2   19세이하   인천광역시 계양구    172
# 3   19세이하   부산광역시 기장군     54
# 4   19세이하    광주광역시 북구     38
# ..    ...         ...    ...
# 95  60세이상   인천광역시 계양구  16231
# 96  60세이상        정보없음  10912
# 97  60세이상  서울특별시 동대문구  10838
# 98  60세이상   서울특별시 용산구  10431
# 99  60세이상   서울특별시 서초구   8824
#
# [100 rows x 3 columns]

# %%
plt.rc('font', family='NanumBarunGothic')

features = ['19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상']
fig, axs = plt.subplots(figsize=(20,20), ncols = 2, nrows=5)

for i, feature in enumerate(lm_features):
    row = int(i/2)
    col = i%2
    # ax(축) 자리 지정
    sns.barplot(data = area_age_top10[area_age_top10['연령대'] == f'{feature}'], x='거주지역', y='분포', ax = axs[row][col]) 
    plt.tight_layout()
    axs[row,col].set_title(f'{feature}')

#plt.savefig('고객연령별_분기금액.png')

# %%
# '19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상'
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(6,6))
plt.rc('font', size=15)

plt.pie(x=area_age_top10[area_age_top10['연령대'] == '19세이하']['분포'],
        labels=area_age_top10[area_age_top10['연령대'] == '19세이하']['거주지역'],
        autopct='%.1f%%')

plt.title("19세이하 지역별 분포")
plt.savefig("19세이하 지역별 분포")

# %%
# '19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상'
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(6,6))
plt.rc('font', size=15)

plt.pie(x=area_age_top10[area_age_top10['연령대'] == '20세~24세']['분포'],
        labels=area_age_top10[area_age_top10['연령대'] == '20세~24세']['거주지역'],
        autopct='%.1f%%')

plt.title("20세~24세 지역별 분포")
plt.savefig("20세~24세 지역별 분포")

# %%
#import seaborn as sns

plt.rc('font', family='NanumBarunGothic')

features = ['19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상']
fig, axs = plt.subplots(figsize=(20,20), ncols = 2, nrows=5)

for i, feature in enumerate(features):
  row = int(i/2)
  col = i%2
  # ax(축) 자리 지정
  #plt.figure(figsize=(6,6))
  plt.rc('font', size=15)
  axs[row,col].pie(data = area_age_top10[area_age_top10['연령대'] == f'{feature}'],
                   x='분포', labels='거주지역', autopct='%.1f%%')
  plt.tight_layout()
  axs[row,col].set_title(f'{feature} 지역별 분포')

plt.savefig('지역별 연령 분포 (top10).png')

# %% [markdown]
# ## 지역별 성별 분포 (top 10)

# %%
market_A
# Out:
#            고객번호 성별      연령대       거주지역 제휴사  중분류명    소분류명    영수증번호  점포코드  \
# 0             1  M    60세이상  서울특별시 강남구   A  일용잡화    위생세제  1456379    12
# 1             1  M    60세이상  서울특별시 강남구   A  일용잡화    위생세제  2751160    12
# 2             1  M    60세이상  서울특별시 강남구   A  일용잡화    위생세제  1307657    12
# 3             1  M    60세이상  서울특별시 강남구   A  일용잡화    위생세제  3960475    12
# 4             1  M    60세이상  서울특별시 강남구   A  일용잡화    위생세제  5602223    12
# ...         ... ..      ...        ...  ..   ...     ...      ...   ...
# 28592783  19383  F  25세~29세   경상남도 함양군   A   캐주얼   영스트리트  4813386    16
# 28592784  19383  F  25세~29세   경상남도 함양군   A   캐주얼   영스트리트  5090339    16
# 28592785  19383  F  25세~29세   경상남도 함양군   A    셔츠   비지니스군  5162132    16
# 28592786  19383  F  25세~29세   경상남도 함양군   A   스포츠    스포츠화  5743419    25
# 28592787  19383  F  25세~29세   경상남도 함양군   A   스포츠  아디다스의류  5114971    47
#
#               구매일자  구매시간   구매금액        분기
# 0         20140228    15   9500  2014_1분기
# ...

# %%
h = market_A.groupby(['성별', '거주지역'])[['거주지역']].count().rename(columns={'거주지역' : '분포'})
h = h.reset_index()
h
# Out:
#    성별          거주지역       분포
# 0   F       강원도 철원군     2701
# 1   F       경기도 김포시  1410480
# 2   F      경상남도 함양군   224216
# 3   F      경상북도 영주시    36747
# 4   F      광주광역시 북구    83178
# .. ..           ...      ...
# 79  M      전라북도 군산시    19696
# 80  M          정보없음    12830
# 81  M   제주특별자치도 제주시        2
# 82  M  충청남도 천안시 동남구     1420
# 83  M      충청북도 단양군     1674
#
# [84 rows x 3 columns]

# %%
s = f.query("연령대 == '19세이하'").sort_values(by='분포', ascending=False)[:10].index
s
# Out:
# Int64Index([5, 1, 8, 3, 2, 0, 9, 7, 4, 6], dtype='int64')

# %%
gender_lst = ['F', 'M']
top_index_lst = []

for gender in gender_lst:
  indx = h.query(f"성별 == '{gender}'").sort_values(by='분포', ascending=False)[:10].index
  for i in range(10):
    top_index_lst.append(indx[i])

top_index_lst
# Out:
# [1, 7, 25, 16, 8, 2, 35, 18, 17, 4, 43, 49, 67, 50, 58, 44, 46, 77, 76, 79]

# %%
# 지역별 성별 분포
area_gender_top10 = h.iloc[top_index_lst]
area_gender_top10 = area_gender_top10.reset_index().iloc[:, 1:]
area_gender_top10
# Out:
#    성별        거주지역       분포
# 0   F     경기도 김포시  1410480
# 1   F   부산광역시 기장군   654473
# 2   F   서울특별시 송파구   462612
# 3   F   서울특별시 노원구   346340
# 4   F   서울특별시 강남구   289205
# 5   F    경상남도 함양군   224216
# 6   F   인천광역시 계양구   147168
# 7   F  서울특별시 동대문구    95615
# 8   F   서울특별시 도봉구    84965
# 9   F    광주광역시 북구    83178
# 10  M     경기도 김포시   287277
# 11  M   부산광역시 기장군   103947
# 12  M   서울특별시 송파구    90461
# 13  M   서울특별시 강남구    65087
# 14  M   서울특별시 노원구    53226
# 15  M    경상남도 함양군    42573
# 16  M    광주광역시 북구    35618
# 17  M   인천광역시 계양구    29722
# 18  M    울산광역시 동구    28270
# 19  M    전라북도 군산시    19696

# %%
# 'F', 'M'
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(6,6))
plt.rc('font', size=15)

plt.pie(x=area_gender_top10[area_gender_top10['성별'] == 'F']['분포'],
        labels=area_gender_top10[area_gender_top10['성별'] == 'F']['거주지역'],
        autopct='%.1f%%')

plt.title("지역별 여성 분포")
plt.savefig("지역별 여성 분포")

# %%
# 'F', 'M'
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(6,6))
plt.rc('font', size=15)

plt.pie(x=area_gender_top10[area_gender_top10['성별'] == 'M']['분포'],
        labels=area_gender_top10[area_gender_top10['성별'] == 'M']['거주지역'],
        autopct='%.1f%%')

plt.title("지역별 남성 분포")
plt.savefig("지역별 남성 분포")

# %% [markdown]
# # 데이터 탐색(2) : 전체 데이터

# %%
buydata_df['분기'] = np.where(buydata_df['구매일자'] < 20140401, '2014_1분기',
                          np.where(buydata_df['구매일자'] < 20140701, '2014_2분기',
                                   np.where(buydata_df['구매일자'] < 20141001, '2014_3분기',
                                            np.where(buydata_df['구매일자'] < 20150101, '2014_4분기',
                                                     np.where(buydata_df['구매일자'] < 20150401, '2015_1분기',
                                                              np.where(buydata_df['구매일자'] < 20150701, '2015_2분기',
                                                                       np.where(buydata_df['구매일자'] < 20151001, '2015_3분기','2015_4분기')))))))

buydata_df[:5]
# Out:
#    고객번호 성별    연령대       거주지역 제휴사  중분류명  소분류명    영수증번호  점포코드      구매일자  구매시간  \
# 0     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  1456379    12  20140228    15
# 1     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  2751160    12  20140919    15
# 2     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  1307657    12  20140130    11
# 3     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  3960475    12  20150327    12
# 4     1  M  60세이상  서울특별시 강남구   A  일용잡화  위생세제  5602223    12  20151130    17
#
#     구매금액        분기
# 0   9500  2014_1분기
# 1   5000  2014_3분기
# 2  19810  2014_1분기
# 3   1000  2015_1분기
# 4   6800  2015_4분기

# %%
buydata_df['구매일자_년도'] = buydata_df['구매일자'].astype('string').str[:4]

# %% [markdown]
# ## 고객의 연령별 분기 구입금액

# %%
age_q = buydata_df.groupby(['연령대', '분기'], as_index=False)[['구매금액']].sum()
age_q
# Out:
#       연령대        분기        구매금액
# 0   19세이하  2014_1분기    14323908
# 1   19세이하  2014_2분기    17101528
# 2   19세이하  2014_3분기    20318814
# 3   19세이하  2014_4분기    24782688
# 4   19세이하  2015_1분기    17921466
# ..    ...       ...         ...
# 75  60세이상  2014_4분기  8742979764
# 76  60세이상  2015_1분기  7209062986
# 77  60세이상  2015_2분기  7478563404
# 78  60세이상  2015_3분기  6852277686
# 79  60세이상  2015_4분기  8849730704
#
# [80 rows x 3 columns]

# %%
age_q['연령대'].unique()[1]
# Out:
# '20세~24세'

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# 고객의 연령별 분기 구매금액
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

fig, axs = plt.subplots(figsize=(20,20), ncols = 2, nrows=5)
lm_features = ['19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상']

for i, feature in enumerate(lm_features):
    row = int(i/2)
    col = i%2
    # ax(축) 자리 지정
    sns.barplot(data = age_q[age_q['연령대'] == f'{feature}'], x='분기', y='구매금액', ax = axs[row][col]) 
    plt.tight_layout()
    axs[row,col].set_title(f'{feature} 분기별 구매금액')

plt.savefig('고객연령별_분기금액(전체데이터).png')

# %% [markdown]
# #### * 분기별 구매금액이 높은 고객의 연령

# %%
age_q['분기'].unique()
# Out:
# array(['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기', '2015_1분기',
#        '2015_2분기', '2015_3분기', '2015_4분기'], dtype=object)

# %%
# 분기별 고객 연령대별 구매금액
#import seaborn as sns

fig, axs = plt.subplots(figsize=(20,20), ncols = 2, nrows=4)
lm_features = ['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기',
               '2015_1분기', '2015_2분기', '2015_3분기', '2015_4분기']

for i, feature in enumerate(lm_features):
    row = int(i/2)
    col = i%2
    # ax(축) 자리 지정
    sns.barplot(data = age_q[age_q['분기'] == f'{feature}'],
                x='연령대', y='구매금액', ax = axs[row][col])
    plt.tight_layout()
    axs[row,col].set_title(f'{feature} 연령대별 구매금액')

plt.savefig('분기별_고객연령별_구매금액(전체데이터).png')

# %% [markdown]
# 연말, 연초가 있는 2014년 4분기부터 2015년 1분기에 매출이 높게 나타났던 것으로 보이고,\
# 주로 30대 후반 ~ 50대 초중반 연령이 구매를 많이 하는 것으로 보인다

# %% [markdown]
# ## 연령별로 분기별 인기있는 점포 번호

# %%
# 연령대별, 분기별, 점포코드 별 총 구매금액
a = buydata_df.groupby(['연령대', '분기', '점포코드'], as_index=False)[['구매금액']].sum()

# %%
a.query("연령대 == '19세이하' & 분기 == '2014_1분기'").sort_values(by='구매금액', ascending=False)

# %%
x = a.query("연령대 == '19세이하' & 분기 == '2014_3분기'").sort_values(by='구매금액', ascending=False)[:1].index
x
# Out:
# Int64Index([24], dtype='int64')

# %%
x[0]
# Out:
# 24

# %%
age_lst = ['19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상']
quarter_lst = ['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기', '2015_1분기', '2015_2분기', '2015_3분기', '2015_4분기']
top_index_lst = []

for age in age_lst:
  for quarter in quarter_lst:
    indx = a.query(f"연령대 == '{age}' & 분기 == '{quarter}'").sort_values(by='구매금액', ascending=False)[:1].index
    top_index_lst.append(indx[0])

top_index_lst

# %%
# 연령별 분기별 인기있는 점포번호
age_quarter_store = a.iloc[top_index_lst]
age_quarter_store = age_quarter_store.reset_index().iloc[:, 1:]
age_quarter_store
# Out:
#       연령대        분기  점포코드        구매금액
# 0   19세이하  2014_1분기    13     2390233
# 1   19세이하  2014_2분기   114     3322026
# 2   19세이하  2014_3분기    16     3789500
# 3   19세이하  2014_4분기    16     7726380
# 4   19세이하  2015_1분기    32     3126827
# ..    ...       ...   ...         ...
# 75  60세이상  2014_4분기     2  1506349993
# 76  60세이상  2015_1분기     2  1130202044
# 77  60세이상  2015_2분기     2  1108830156
# 78  60세이상  2015_3분기     2  1136710072
# 79  60세이상  2015_4분기     2  1484424824
#
# [80 rows x 4 columns]

# %%
age_quarter_store['점포코드'].unique()
# Out:
# array([ 13, 114,  16,  32,  29,  24,   1,   2,   4,  37])

# %%
import plotly.express as px

fig = px.bar(age_quarter_store, x='분기', y='구매금액',
             color='연령대', text="점포코드", barmode='group', height=400,
             title='연령별 분기별 인기있는 점포번호')
fig.update_traces(textfont_size=15, textangle=0, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 성별 분기별 인기있는 점포 번호

# %%
# 성별, 분기별, 점포코드 별 총 구매금액
b = buydata_df.groupby(['성별', '분기', '점포코드'], as_index=False)[['구매금액']].sum()
b
# Out:
#      성별        분기  점포코드        구매금액
# 0     F  2014_1분기     1  4491708139
# 1     F  2014_1분기     2  6747005144
# 2     F  2014_1분기     3  1372799055
# 3     F  2014_1분기     4  3158440555
# 4     F  2014_1분기     5   401294747
# ...  ..       ...   ...         ...
# 8139  M  2015_4분기   587        2970
# 8140  M  2015_4분기   590       26880
# 8141  M  2015_4분기   591        9540
# 8142  M  2015_4분기   592      581810
# 8143  M  2015_4분기   593      124940
#
# [8144 rows x 4 columns]

# %%
gender_lst = ['F', 'M']
quarter_lst = ['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기', '2015_1분기', '2015_2분기', '2015_3분기', '2015_4분기']
top_index_lst = []

for gender in gender_lst:
  for quarter in quarter_lst:
    indx = b.query(f"성별 == '{gender}' & 분기 == '{quarter}'").sort_values(by='구매금액', ascending=False)[:1].index
    top_index_lst.append(indx[0])

top_index_lst

# %%
# 성별 분기별 인기있는 점포번호
gender_quarter_store = b.iloc[top_index_lst]
gender_quarter_store = gender_quarter_store.reset_index().iloc[:, 1:]
gender_quarter_store
# Out:
#    성별        분기  점포코드        구매금액
# 0   F  2014_1분기     2  6747005144
# 1   F  2014_2분기     2  6942620343
# 2   F  2014_3분기     2  6340388837
# 3   F  2014_4분기     2  7423815254
# 4   F  2015_1분기     2  6226183168
# 5   F  2015_2분기     2  6738660794
# 6   F  2015_3분기     2  6189363545
# 7   F  2015_4분기     2  8234131442
# 8   M  2014_1분기     2  1279673802
# 9   M  2014_2분기     2  1617093090
# 10  M  2014_3분기     2  1361878625
# 11  M  2014_4분기     1  2345053702
# 12  M  2015_1분기     2  1748087727
# 13  M  2015_2분기     1  1884682466
# 14  M  2015_3분기     2  1638028812
# 15  M  2015_4분기     1  2074851905

# %%
import plotly.express as px

fig = px.bar(gender_quarter_store, x='분기', y='구매금액',
             color='성별', text="점포코드", barmode='group', height=400,
             title='성별 분기별 인기있는 점포번호')
fig.update_traces(textfont_size=15, textangle=0, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 연령별 분기별 인기있는 구입 상품

# %%
# 연령대별, 분기별, 인기 구매 상품
c = buydata_df.groupby(['연령대', '분기', '중분류명'], as_index=False)[['소분류명']].count().rename(columns={'소분류명' : '구매횟수'})
c
# Out:
#          연령대        분기   중분류명  구매횟수
# 0      19세이하  2014_1분기  가공분말류     4
# 1      19세이하  2014_1분기   가공식품    25
# 2      19세이하  2014_1분기   가공우유     4
# 3      19세이하  2014_1분기     가루     3
# 4      19세이하  2014_1분기     가방     1
# ...      ...       ...    ...   ...
# 37570  60세이상  2015_4분기     황태   139
# 37571  60세이상  2015_4분기  훼이셜케어    51
# 37572  60세이상  2015_4분기  휴대폰용품     9
# 37573  60세이상  2015_4분기    휴지통    11
# 37574  60세이상  2015_4분기    흰우유  3368
#
# [37575 rows x 4 columns]

# %%
age_lst = ['19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상']
quarter_lst = ['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기', '2015_1분기', '2015_2분기', '2015_3분기', '2015_4분기']
top_index_lst = []

for age in age_lst:
  for quarter in quarter_lst:
    indx = c.query(f"연령대 == '{age}' & 분기 == '{quarter}'").sort_values(by='구매횟수', ascending=False)[:1].index
    top_index_lst.append(indx[0])

top_index_lst

# %%
# 연령별 분기별 인기 구매 상품
age_quarter_product = c.iloc[top_index_lst]
age_quarter_product = age_quarter_product.reset_index().iloc[:, 1:]
age_quarter_product
# Out:
#       연령대        분기  중분류명   구매횟수
# 0   19세이하  2014_1분기    스낵    113
# 1   19세이하  2014_2분기    스낵     96
# 2   19세이하  2014_3분기   과채류     73
# 3   19세이하  2014_4분기    라면     78
# 4   19세이하  2015_1분기    스낵    120
# ..    ...       ...   ...    ...
# 75  60세이상  2014_4분기  가공식품  13434
# 76  60세이상  2015_1분기  가공식품  13264
# 77  60세이상  2015_2분기   농산물  13782
# 78  60세이상  2015_3분기  가공식품  13856
# 79  60세이상  2015_4분기  가공식품  13491
#
# [80 rows x 4 columns]

# %%
age_quarter_product['중분류명'].unique()
# Out:
# array(['스낵', '과채류', '라면', '아이스크림', '가공식품', '농산물'], dtype=object)

# %%
import plotly.express as px

fig = px.bar(age_quarter_product, x='분기', y='구매횟수',
             color='연령대', text="중분류명", barmode='group', height=400,
             title="연령별 분기별 인기 구매 상품")
fig.update_traces(textfont_size=15, textangle=90, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

fig = px.bar(age_quarter_product, x='연령대', y='구매횟수',
             color='분기', text="중분류명", barmode='group', height=400,
             title="연령별 분기별 인기 구매 상품")
fig.update_traces(textfont_size=15, textangle=90, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 연령별 분기별 인기있는 구입 상품 (소분류명으로 분류)

# %%
# 연령별 분기별 인기있는 구입 상품 (소분류명)
g = buydata_df.groupby(['연령대', '분기', '중분류명', '소분류명'])[['소분류명']].count().rename(columns={'소분류명' : '구매횟수'})
g = g.reset_index()
g
# Out:
#           연령대        분기   중분류명         소분류명  구매횟수
# 0       19세이하  2014_1분기  가공분말류  도넛가루/핫케이크가루     1
# 1       19세이하  2014_1분기  가공분말류          밀가루     1
# 2       19세이하  2014_1분기  가공분말류         부침가루     1
# 3       19세이하  2014_1분기  가공분말류         튀김가루     1
# 4       19세이하  2014_1분기   가공식품            떡     1
# ...       ...       ...    ...          ...   ...
# 179047  60세이상  2015_4분기    흰우유        기능성우유  1443
# 179048  60세이상  2015_4분기    흰우유        멸균흰우유    64
# 179049  60세이상  2015_4분기    흰우유        어린이우유   169
# 179050  60세이상  2015_4분기    흰우유        일반흰우유  1617
# 179051  60세이상  2015_4분기    흰우유        친환경우유    75
#
# [179052 rows x 5 columns]

# %%
g.query("연령대 == '30세~34세' & 분기 == '2014_1분기'").sort_values(by='구매횟수', ascending=False)[:1]
# Out:
#            연령대        분기  중분류명   소분류명  구매횟수
# 38850  30세~34세  2014_1분기  청소용품  종량제봉투  2986

# %%
age_lst = ['19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상']
quarter_lst = ['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기', '2015_1분기', '2015_2분기', '2015_3분기', '2015_4분기']
top_index_lst = []

for age in age_lst:
  for quarter in quarter_lst:
    indx = g.query(f"연령대 == '{age}' & 분기 == '{quarter}'").sort_values(by='구매횟수', ascending=False)[:1].index
    top_index_lst.append(indx[0])

top_index_lst

# %%
# 연령별 분기별 인기있는 구입 상품 (소분류명)
age_quarter_small_product = g.iloc[top_index_lst]
age_quarter_small_product = age_quarter_small_product.reset_index().iloc[:, 1:]
age_quarter_small_product
# Out:
#       연령대        분기    중분류명   소분류명  구매횟수
# 0   19세이하  2014_1분기    청소용품  종량제봉투    53
# 1   19세이하  2014_2분기    청소용품  종량제봉투    70
# 2   19세이하  2014_3분기    청소용품  종량제봉투    53
# 3   19세이하  2014_4분기    냉장수산     어묵    45
# 4   19세이하  2015_1분기  청소욕실용품  종량제봉투    53
# ..    ...       ...     ...    ...   ...
# 75  60세이상  2014_4분기     농산물     청과  3340
# 76  60세이상  2015_1분기     농산물     채소  3268
# 77  60세이상  2015_2분기     농산물     청과  3902
# 78  60세이상  2015_3분기     농산물  유기농채소  3196
# 79  60세이상  2015_4분기     농산물  유기농채소  3102
#
# [80 rows x 5 columns]

# %%
age_quarter_small_product['소분류명'].unique()
# Out:
# array(['종량제봉투', '어묵', '감자스낵', '주방균일가', '일반스낵', '생수', '다이소', '재사용봉투',
#        '국산맥주', '일반흰우유', '청과', '유제품', '채소', '유기농채소'], dtype=object)

# %%
import plotly.express as px

fig = px.bar(age_quarter_small_product.query("분기 in ['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기']"),
             x='연령대', y='구매횟수', color='분기', text="소분류명", barmode='group', height=400,
             title='연령별 2014년도 분기별 인기있는 구입 상품 (소분류명으로 분류)')
fig.update_traces(textfont_size=40, textangle=90, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# '19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상'
import plotly.express as px

fig = px.bar(age_quarter_small_product.query("분기 in ['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기'] & 연령대 in ['19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세']"),
             x='연령대', y='구매횟수', color='분기', text="소분류명", barmode='group', height=400,
             title='10~30대 2014년도 분기별 인기있는 구입 상품 (소분류명으로 분류)')
fig.update_traces(textfont_size=40, textangle=90, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# '19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상'
import plotly.express as px

fig = px.bar(age_quarter_small_product.query("분기 in ['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기'] & 연령대 in ['40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상']"),
             x='연령대', y='구매횟수', color='분기', text="소분류명", barmode='group', height=400,
             title='40대 이상 2014년도 분기별 인기있는 구입 상품 (소분류명으로 분류)')
fig.update_traces(textfont_size=15, textangle=90, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

fig = px.bar(age_quarter_small_product.query("분기 in ['2015_1분기', '2015_2분기', '2015_3분기', '2015_4분기']"),
             x='연령대', y='구매횟수', color='분기', text="소분류명", barmode='group', height=400,
             title='연령별 2015년도 분기별 인기있는 구입 상품 (소분류명으로 분류)')
fig.update_traces(textfont_size=40, textangle=90, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# '19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상'
import plotly.express as px

fig = px.bar(age_quarter_small_product.query("분기 in ['2015_1분기', '2015_2분기', '2015_3분기', '2015_4분기'] & 연령대 in ['19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세']"),
             x='연령대', y='구매횟수', color='분기', text="소분류명", barmode='group', height=400,
             title='10~30대 2015년도 분기별 인기있는 구입 상품 (소분류명으로 분류)')
fig.update_traces(textfont_size=40, textangle=90, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# '19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상'
import plotly.express as px

fig = px.bar(age_quarter_small_product.query("분기 in ['2015_1분기', '2015_2분기', '2015_3분기', '2015_4분기'] & 연령대 in ['40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상']"),
             x='연령대', y='구매횟수', color='분기', text="소분류명", barmode='group', height=400,
             title='40대 이상 2015년도 분기별 인기있는 구입 상품 (소분류명으로 분류)')
fig.update_traces(textfont_size=15, textangle=90, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 성별 분기별 인기있는 구입 상품

# %%
# 성별, 분기별 인기있는 구입 상품
d = buydata_df.groupby(['성별', '분기', '중분류명'], as_index=False)[['소분류명']].count().rename(columns={'소분류명' : '구매횟수'})
d
# Out:
#      성별        분기         중분류명  구매횟수
# 0     F  2014_1분기  BABY/INFANT  1372
# 1     F  2014_1분기    Fast Food   547
# 2     F  2014_1분기        GIRLS  1101
# 3     F  2014_1분기      H&B선물세트   346
# 4     F  2014_1분기      MP3/PMP     2
# ...  ..       ...          ...   ...
# 8263  M  2015_4분기           황태   239
# 8264  M  2015_4분기        훼이셜케어   205
# 8265  M  2015_4분기        휴대폰용품    61
# 8266  M  2015_4분기          휴지통    41
# 8267  M  2015_4분기          흰우유  8789
#
# [8268 rows x 4 columns]

# %%
gender_lst = ['F', 'M']
quarter_lst = ['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기', '2015_1분기', '2015_2분기', '2015_3분기', '2015_4분기']
top_index_lst = []

for gender in gender_lst:
  for quarter in quarter_lst:
    indx = d.query(f"성별 == '{gender}' & 분기 == '{quarter}'").sort_values(by='구매횟수', ascending=False)[:1].index
    top_index_lst.append(indx[0])

top_index_lst
# Out:
# [13,
#  449,
#  885,
#  1529,
#  2064,
#  2604,
#  3134,
#  3670,
#  4201,
#  4628,
#  5055,
#  5652,
#  6178,
#  6712,
#  7232,
#  7761]

# %%
# 성별, 분기별 인기있는 구입 상품
gender_quarter_product = d.iloc[top_index_lst]
gender_quarter_product = gender_quarter_product.reset_index().iloc[:, 1:]
gender_quarter_product
# Out:
#    성별        분기  중분류명    구매횟수
# 0   F  2014_1분기  가공식품  115540
# 1   F  2014_2분기  가공식품  124319
# 2   F  2014_3분기  가공식품  130115
# 3   F  2014_4분기  가공식품  136478
# 4   F  2015_1분기  가공식품  134533
# 5   F  2015_2분기  가공식품  134314
# 6   F  2015_3분기  가공식품  137312
# 7   F  2015_4분기  가공식품  133930
# 8   M  2014_1분기  가공식품   23576
# 9   M  2014_2분기  가공식품   25708
# 10  M  2014_3분기  가공식품   26553
# 11  M  2014_4분기  가공식품   27876
# 12  M  2015_1분기  가공식품   27744
# 13  M  2015_2분기  가공식품   27547
# 14  M  2015_3분기  가공식품   27969
# 15  M  2015_4분기  가공식품   27201

# %%
gender_quarter_product['중분류명'].unique()
# Out:
# array(['가공식품'], dtype=object)

# %%
import plotly.express as px

fig = px.bar(gender_quarter_product, x='분기', y='구매횟수',
             color='성별', text="중분류명", barmode='group', height=400,
             title='성별 분기별 인기있는 구입 상품')
fig.update_traces(textfont_size=15, textangle=0, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### 성별 분기별 인기있는 구입 상품 (소분류명으로 분류)

# %%
# 성별, 분기별 인기있는 구입 상품 (소분류명)
e = buydata_df.groupby(['성별', '분기', '중분류명', '소분류명'])[['소분류명']].count().rename(columns={'소분류명' : '구매횟수'})
e = e.reset_index()
e
# Out:
#       성별        분기         중분류명        소분류명  구매횟수
# 0      F  2014_1분기  BABY/INFANT         기저귀     2
# 1      F  2014_1분기  BABY/INFANT         미취학   426
# 2      F  2014_1분기  BABY/INFANT    발육기 액세서리    37
# 3      F  2014_1분기  BABY/INFANT       베이비푸드   107
# 4      F  2014_1분기  BABY/INFANT  스킨케어 및 물티슈   177
# ...   ..       ...          ...         ...   ...
# 44578  M  2015_4분기          흰우유       기능성우유  2885
# 44579  M  2015_4분기          흰우유       멸균흰우유   174
# 44580  M  2015_4분기          흰우유       어린이우유   480
# 44581  M  2015_4분기          흰우유       일반흰우유  5097
# 44582  M  2015_4분기          흰우유       친환경우유   153
#
# [44583 rows x 5 columns]

# %%
gender_lst = ['F', 'M']
quarter_lst = ['2014_1분기', '2014_2분기', '2014_3분기', '2014_4분기', '2015_1분기', '2015_2분기', '2015_3분기', '2015_4분기']
top_index_lst = []

for gender in gender_lst:
  for quarter in quarter_lst:
    indx = e.query(f"성별 == '{gender}' & 분기 == '{quarter}'").sort_values(by='구매횟수', ascending=False)[:1].index
    top_index_lst.append(indx[0])

top_index_lst
# Out:
# [1317,
#  3808,
#  6731,
#  9846,
#  12783,
#  15684,
#  18665,
#  21701,
#  24372,
#  26696,
#  28695,
#  32169,
#  34926,
#  37658,
#  39849,
#  43280]

# %%
# 성별, 분기별 인기있는 구입 상품
gender_quarter_small_product = e.iloc[top_index_lst]
gender_quarter_small_product = gender_quarter_small_product.reset_index().iloc[:, 1:]
gender_quarter_small_product
# Out:
#    성별        분기 중분류명  소분류명   구매횟수
# 0   F  2014_1분기   스낵  일반스낵  30804
# 1   F  2014_2분기   스낵  일반스낵  34918
# 2   F  2014_3분기   스낵  일반스낵  34684
# 3   F  2014_4분기   스낵  일반스낵  36207
# 4   F  2015_1분기   스낵  일반스낵  38421
# 5   F  2015_2분기   스낵  일반스낵  34469
# 6   F  2015_3분기   스낵  일반스낵  35242
# 7   F  2015_4분기   스낵  일반스낵  34064
# 8   M  2014_1분기   스낵  일반스낵   7527
# 9   M  2014_2분기   스낵  일반스낵   8367
# 10  M  2014_3분기   맥주  국산맥주   8819
# 11  M  2014_4분기   스낵  일반스낵   8799
# 12  M  2015_1분기   스낵  일반스낵   9314
# 13  M  2015_2분기   스낵  일반스낵   8636
# 14  M  2015_3분기   맥주  국산맥주   9089
# 15  M  2015_4분기   스낵  일반스낵   8529

# %%
gender_quarter_small_product['소분류명'].unique()
# Out:
# array(['일반스낵', '국산맥주'], dtype=object)

# %%
import plotly.express as px

fig = px.bar(gender_quarter_small_product, x='분기', y='구매횟수',
             color='성별', text="소분류명", barmode='group', height=400,
             title='성별 분기별 인기있는 구입 상품 (소분류명으로 분류)')
fig.update_traces(textfont_size=15, textangle=0, textposition="outside", cliponaxis=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 지역별 연령 분포 (top 10)

# %%
f = buydata_df.groupby(['연령대', '거주지역'])[['거주지역']].count().rename(columns={'거주지역' : '분포'})
f = f.reset_index()
f
# Out:
#        연령대          거주지역     분포
# 0    19세이하       경기도 김포시   6365
# 1    19세이하      경상남도 함양군    337
# 2    19세이하      광주광역시 북구   1815
# 3    19세이하     부산광역시 기장군   2311
# 4    19세이하     서울특별시 강남구   2825
# ..     ...           ...    ...
# 374  60세이상      전라남도 영광군   9134
# 375  60세이상      전라북도 군산시  13711
# 376  60세이상          정보없음  22342
# 377  60세이상  충청남도 천안시 동남구  12558
# 378  60세이상      충청북도 단양군  20597
#
# [379 rows x 3 columns]

# %%
s = f.query("연령대 == '19세이하'").sort_values(by='분포', ascending=False)[:10].index
s
# Out:
# Int64Index([5, 1, 8, 3, 2, 0, 9, 7, 4, 6], dtype='int64')

# %%
age_lst = ['19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상']
top_index_lst = []

for age in age_lst:
  indx = f.query(f"연령대 == '{age}'").sort_values(by='분포', ascending=False)[:10].index
  for i in range(10):
    top_index_lst.append(indx[i])

top_index_lst

# %%
# 지역별 연령 분포
area_age_top10 = f.iloc[top_index_lst]
area_age_top10 = area_age_top10.reset_index().iloc[:, 1:]
area_age_top10
# Out:
#       연령대        거주지역     분포
# 0   19세이하     경기도 김포시   6365
# 1   19세이하   서울특별시 강남구   2825
# 2   19세이하    전라북도 군산시   2525
# 3   19세이하   인천광역시 계양구   2385
# 4   19세이하   부산광역시 기장군   2311
# ..    ...         ...    ...
# 95  60세이상   인천광역시 계양구  78507
# 96  60세이상   서울특별시 광진구  64978
# 97  60세이상  서울특별시 동대문구  49349
# 98  60세이상    광주광역시 북구  30245
# 99  60세이상   서울특별시 용산구  22801
#
# [100 rows x 3 columns]

# %%
#import seaborn as sns

plt.rc('font', family='NanumBarunGothic')

features = ['19세이하', '20세~24세', '25세~29세', '30세~34세', '35세~39세', '40세~44세', '45세~49세', '50세~54세', '55세~59세', '60세이상']
fig, axs = plt.subplots(figsize=(20,20), ncols = 2, nrows=5)

for i, feature in enumerate(features):
  row = int(i/2)
  col = i%2
  # ax(축) 자리 지정
  #plt.figure(figsize=(6,6))
  plt.rc('font', size=15)
  axs[row,col].pie(data = area_age_top10[area_age_top10['연령대'] == f'{feature}'],
                   x='분포', labels='거주지역', autopct='%.1f%%')
  plt.tight_layout()
  axs[row,col].set_title(f'{feature} 지역별 분포')

plt.savefig('전체)지역별 연령 분포 (top10).png')

# %% [markdown]
# ## 지역별 성별 분포 (top 10)

# %%
h = buydata_df.groupby(['성별', '거주지역'])[['거주지역']].count().rename(columns={'거주지역' : '분포'})
h = h.reset_index()
h
# Out:
#    성별          거주지역       분포
# 0   F       강원도 철원군   259758
# 1   F       경기도 김포시  7518578
# 2   F      경상남도 함양군   993664
# 3   F      경상북도 영주시   425303
# 4   F      광주광역시 북구   748350
# .. ..           ...      ...
# 79  M      전라북도 군산시   164469
# 80  M          정보없음    45381
# 81  M   제주특별자치도 제주시      839
# 82  M  충청남도 천안시 동남구    86343
# 83  M      충청북도 단양군   132678
#
# [84 rows x 3 columns]

# %%
s = f.query("연령대 == '19세이하'").sort_values(by='분포', ascending=False)[:10].index
s
# Out:
# Int64Index([5, 1, 8, 3, 2, 0, 9, 7, 4, 6], dtype='int64')

# %%
gender_lst = ['F', 'M']
top_index_lst = []

for gender in gender_lst:
  indx = h.query(f"성별 == '{gender}'").sort_values(by='분포', ascending=False)[:10].index
  for i in range(10):
    top_index_lst.append(indx[i])

top_index_lst
# Out:
# [1, 7, 25, 35, 2, 16, 4, 37, 8, 41, 43, 49, 67, 77, 44, 46, 79, 50, 58, 78]

# %%
# 지역별 성별 분포
area_gender_top10 = h.iloc[top_index_lst]
area_gender_top10 = area_gender_top10.reset_index().iloc[:, 1:]
area_gender_top10
# Out:
#    성별       거주지역       분포
# 0   F    경기도 김포시  7518578
# 1   F  부산광역시 기장군  2101967
# 2   F  서울특별시 송파구  1827202
# 3   F  인천광역시 계양구  1429499
# 4   F   경상남도 함양군   993664
# 5   F  서울특별시 노원구   985594
# 6   F   광주광역시 북구   748350
# 7   F   전라북도 군산시   659954
# 8   F  서울특별시 강남구   639416
# 9   F   충청북도 단양군   487049
# 10  M    경기도 김포시  1529462
# 11  M  부산광역시 기장군   431194
# 12  M  서울특별시 송파구   361166
# 13  M  인천광역시 계양구   301713
# 14  M   경상남도 함양군   234750
# 15  M   광주광역시 북구   224388
# 16  M   전라북도 군산시   164469
# 17  M  서울특별시 강남구   156276
# 18  M  서울특별시 노원구   154376
# 19  M   전라남도 영광군   150762

# %%
# 'F', 'M'
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(6,6))
plt.rc('font', size=15)

plt.pie(x=area_gender_top10[area_gender_top10['성별'] == 'F']['분포'],
        labels=area_gender_top10[area_gender_top10['성별'] == 'F']['거주지역'],
        autopct='%.1f%%')

plt.title("지역별 여성 분포")
plt.savefig("전체)지역별 여성 분포")

# %%
# 'F', 'M'
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')
plt.figure(figsize=(6,6))
plt.rc('font', size=15)

plt.pie(x=area_gender_top10[area_gender_top10['성별'] == 'M']['분포'],
        labels=area_gender_top10[area_gender_top10['성별'] == 'M']['거주지역'],
        autopct='%.1f%%')

plt.title("지역별 남성 분포")
plt.savefig("전체)지역별 남성 분포")

# %%
buydata_df[buydata_df['소분류명'] == '종량제봉투']
# Out:
#            고객번호 성별      연령대       거주지역 제휴사    중분류명   소분류명     영수증번호  점포코드  \
# 1045          1  M    60세이상  서울특별시 강남구   C  청소욕실용품  종량제봉투  10976489   318
# 1046          1  M    60세이상  서울특별시 강남구   C  청소욕실용품  종량제봉투  10975866   318
# 1047          1  M    60세이상  서울특별시 강남구   C  청소욕실용품  종량제봉투  10972931   318
# 1048          1  M    60세이상  서울특별시 강남구   C  청소욕실용품  종량제봉투    410434   318
# 1049          1  M    60세이상  서울특별시 강남구   C  청소욕실용품  종량제봉투   5846388    96
# ...         ... ..      ...        ...  ..     ...    ...       ...   ...
# 28590030  19378  F  45세~49세    경기도 김포시   C  청소욕실용품  종량제봉투    151823     7
# 28590117  19379  F  20세~24세  서울특별시 동작구   C  청소욕실용품  종량제봉투   7506381   242
# 28590118  19379  F  20세~24세  서울특별시 동작구   C  청소욕실용품  종량제봉투   7506349   242
# 28592769  19382  F  45세~49세  부산광역시 기장군   C  청소욕실용품  종량제봉투   7505978   241
# 28592806  19383  F  25세~29세   경상남도 함양군   C  청소욕실용품  종량제봉투    796639    49
#
#               구매일자  구매시간  구매금액        분기
# ...
